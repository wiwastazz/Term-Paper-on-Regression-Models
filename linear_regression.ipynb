# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Обычная линейная регрессия (одномерная)

# %%
from sklearn.datasets import make_regression

X, y = make_regression (n_samples = 50, n_features= 1,  n_informative = 1, noise = 10, random_state = 11)
#display(X, y)

# %%
fig = plt.figure ( figsize = (10, 6))
plt.scatter(X, y)

plt.xlabel('Feature')
plt.ylabel('Target')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X, y)

print(model.coef_ , model.intercept_)
sklearn_a =  model.coef_[0]
sklearn_b = model.intercept_
# Out:
# [80.41862354] 0.1817188754210104

# %%
x_feature = np.arange(-3, 3)
model_y_sklearn = sklearn_a*x_feature + sklearn_b

fig = plt.figure(figsize = (10, 6))
plt.plot(x_feature, model_y_sklearn, color = 'r')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.scatter(X, y)
plt.show()
print(f'Линейная модель вида: {sklearn_a}x + {sklearn_b}')
# Out:
# Линейная модель вида: 80.41862353979872x + 0.1817188754210104

# %% [markdown]
# Пример предсказания:

# %%
x = 0
y_target = sklearn_a*x+ sklearn_b

plt.scatter(x, y_target)
plt.plot(x_feature, model_y_sklearn, color = 'r')
plt.show()

# %% [markdown]
# своя реализация

# %%
df = pd.DataFrame({'X': X[:, 0], 'y' : y, 'prediction' : sklearn_a*X[:, 0]+ sklearn_b})
df.head()
# Out:
#           X           y  prediction
# 0  0.630080   43.654341   50.851871
# 1 -1.061634  -72.682350  -85.193462
# 2  0.296347   21.196446   24.013545
# 3  1.402771  107.587651  112.990641
# 4  0.689682   69.620632   55.645021

# %%
def MSE(X, w1, w0, y):
    y_pred = w1*X[:, 0] + w0
    return np.sum( (y-y_pred)**2 / (len(y_pred)+1)) 

def MSE_grad_w0(X, w1, w0, y):
    y_pred = w1*X[:, 0] + w0
    return 2/(len(X)+1) * np.sum( (y - y_pred ))*(-1) # -1 - производная по w0  
                     
def MSE_grad_w1(X, w1, w0, y):
    y_pred = w1*X[:, 0] + w0
    return 2/(len(X)+1) * np.sum( (y - y_pred)* np.array( [-X[:,0]])) # -X - производная по w1

# %%
# начальная точка

w1 = 0
w0 = 0

learning_rate = 0.01

next_w1 = w1
next_w0 = w0

max_iterations = 1000
eps = 10**(-6)
it = 1
while (it <= max_iterations):
    cur_w1 = next_w1
    cur_w0 = next_w0
    
    next_w1 =  cur_w1 - learning_rate * MSE_grad_w1(X, cur_w1, cur_w0, y)
    next_w0 =  cur_w0 - learning_rate * MSE_grad_w0(X, cur_w1, cur_w0, y)
    
    print(f'Итерация: {it}')
    print(f'Текущая точка: {cur_w1}x + {cur_w0}')
    print(f'Следующая точка: {next_w1}x + {next_w0}')
    print(f'Mean Squared Error: {round(MSE(X, cur_w1, cur_w0, y), 3)}')
    print('-' * 60)
    it+=1
    if abs(cur_w1 - next_w1) <= eps and abs(cur_w0 - next_w0) <= eps:
        break
# Out:
# Итерация: 1
# Текущая точка: 0x + 0
# Следующая точка: 1.298539813557112x + -0.13648773069168443
# Mean Squared Error: 5329.835
# ------------------------------------------------------------
# Итерация: 2
# Текущая точка: 1.298539813557112x + -0.13648773069168443
# Следующая точка: 2.575868970426488x + -0.26803779500950453
# Mean Squared Error: 5160.763
# ------------------------------------------------------------
# Итерация: 3
# Текущая точка: 2.575868970426488x + -0.26803779500950453
# Следующая точка: 3.8323386469622345x + -0.39478394877798945
# Mean Squared Error: 4997.239
# ------------------------------------------------------------
# Итерация: 4
# Текущая точка: 3.8323386469622345x + -0.39478394877798945
# Следующая точка: 5.068294114664474x + -0.5168567135769045
# Mean Squared Error: 4839.079
# ------------------------------------------------------------
# Итерация: 5
# Текущая точка: 5.068294114664474x + -0.5168567135769045
# Следующая точка: 6.284074841182259x + -0.6343834504412516
# Mean Squared Error: 4686.105
# ------------------------------------------------------------
# Итерация: 6
# Текущая точка: 6.284074841182259x + -0.6343834504412516
# Следующая точка: 7.48001458955682x + -0.7474884319402723
# Mean Squared Error: 4538.144
# ------------------------------------------------------------
# Итерация: 7
# Текущая точка: 7.48001458955682x + -0.7474884319402723
# Следующая точка: 8.65644151573639x + -0.8562929126703036
# Mean Squared Error: 4395.028
# ------------------------------------------------------------
# Итерация: 8
# Текущая точка: 8.65644151573639x + -0.8562929126703036
# Следующая точка: 9.813678264393282x + -0.9609151981955959
# Mean Squared Error: 4256.598
# ------------------------------------------------------------
# Итерация: 9
# Текущая точка: 9.813678264393282x + -0.9609151981955959
# Следующая точка: 10.95204206307335x + -1.0614707124704827
# Mean Squared Error: 4122.697
# ------------------------------------------------------------
# Итерация: 10
# Текущая точка: 10.95204206307335x + -1.0614707124704827
# Следующая точка: 12.071844814707399x + -1.1580720637755837
# Mean Squared Error: 3993.175
# ------------------------------------------------------------
# Итерация: 11
# Текущая точка: 12.071844814707399x + -1.1580720637755837
# Следующая точка: 13.173393188513607x + -1.2508291092000305
# Mean Squared Error: 3867.887
# ------------------------------------------------------------
# Итерация: 12
# Текущая точка: 13.173393188513607x + -1.2508291092000305
# Следующая точка: 14.256988709319458x + -1.3398490177010267
# Mean Squared Error: 3746.692
# ------------------------------------------------------------
# Итерация: 13
# Текущая точка: 14.256988709319458x + -1.3398490177010267
# Следующая точка: 15.322927845331202x + -1.4252363317713888
# Mean Squared Error: 3629.454
# ------------------------------------------------------------
# Итерация: 14
# Текущая точка: 15.322927845331202x + -1.4252363317713888
# Следующая точка: 16.371502094378346x + -1.507093027745068
# Mean Squared Error: 3516.043
# ------------------------------------------------------------
# Итерация: 15
# Текущая точка: 16.371502094378346x + -1.507093027745068
# Следующая точка: 17.402998068660164x + -1.5855185747700142
# Mean Squared Error: 3406.331
# ------------------------------------------------------------
# Итерация: 16
# Текущая точка: 17.402998068660164x + -1.5855185747700142
# Следующая точка: 18.41769757802074x + -1.6606099924771203
# Mean Squared Error: 3300.197
# ------------------------------------------------------------
# Итерация: 17
# Текущая точка: 18.41769757802074x + -1.6606099924771203
# Следующая точка: 19.41587771177861x + -1.732461907373379
# Mean Squared Error: 3197.522
# ------------------------------------------------------------
# Итерация: 18
# Текущая точка: 19.41587771177861x + -1.732461907373379
# Следующая точка: 20.39781091913653x + -1.8011666079867816
# Mean Squared Error: 3098.192
# ------------------------------------------------------------
# Итерация: 19
# Текущая точка: 20.39781091913653x + -1.8011666079867816
# Следующая точка: 21.36376508819649x + -1.8668140987899113
# Mean Squared Error: 3002.095
# ------------------------------------------------------------
# Итерация: 20
# Текущая точка: 21.36376508819649x + -1.8668140987899113
# Следующая точка: 22.314003623604666x + -1.9294921529286015
# Mean Squared Error: 2909.126
# ------------------------------------------------------------
# Итерация: 21
# Текущая точка: 22.314003623604666x + -1.9294921529286015
# Следующая точка: 23.248785522850437x + -1.989286363781481
# Mean Squared Error: 2819.182
# ------------------------------------------------------------
# Итерация: 22
# Текущая точка: 23.248785522850437x + -1.989286363781481
# Следующая точка: 24.16836545124333x + -2.04628019537567
# Mean Squared Error: 2732.161
# ------------------------------------------------------------
# Итерация: 23
# Текущая точка: 24.16836545124333x + -2.04628019537567
# Следующая точка: 25.072993815591175x + -2.10055503168336
# Mean Squared Error: 2647.969
# ------------------------------------------------------------
# Итерация: 24
# Текущая точка: 25.072993815591175x + -2.10055503168336
# Следующая точка: 25.962916836602442x + -2.1521902248234794
# Mean Squared Error: 2566.511
# ------------------------------------------------------------
# Итерация: 25
# Текущая точка: 25.962916836602442x + -2.1521902248234794
# Следующая точка: 26.838376620035216x + -2.201263142192143
# Mean Squared Error: 2487.699
# ------------------------------------------------------------
# Итерация: 26
# Текущая точка: 26.838376620035216x + -2.201263142192143
# Следующая точка: 27.69961122661499x + -2.2478492125450615
# Mean Squared Error: 2411.444
# ------------------------------------------------------------
# Итерация: 27
# Текущая точка: 27.69961122661499x + -2.2478492125450615
# Следующая точка: 28.546854740742916x + -2.2920219710546164
# Mean Squared Error: 2337.662
# ------------------------------------------------------------
# Итерация: 28
# Текущая точка: 28.546854740742916x + -2.2920219710546164
# Следующая точка: 29.3803373380159x + -2.3338531033638006
# Mean Squared Error: 2266.273
# ------------------------------------------------------------
# Итерация: 29
# Текущая точка: 29.3803373380159x + -2.3338531033638006
# Следующая точка: 30.20028535157941x + -2.373412488658774
# Mean Squared Error: 2197.198
# ------------------------------------------------------------
# Итерация: 30
# Текущая точка: 30.20028535157941x + -2.373412488658774
# Следующая точка: 31.00692133733364x + -2.4107682417813
# Mean Squared Error: 2130.36
# ------------------------------------------------------------
# Итерация: 31
# Текущая точка: 31.00692133733364x + -2.4107682417813
# Следующая точка: 31.800464138013133x + -2.445986754401891
# Mean Squared Error: 2065.686
# ------------------------------------------------------------
# Итерация: 32
# Текущая точка: 31.800464138013133x + -2.445986754401891
# Следующая точка: 32.581128946159765x + -2.4791327352740438
# Mean Squared Error: 2003.106
# ------------------------------------------------------------
# Итерация: 33
# Текущая точка: 32.581128946159765x + -2.4791327352740438
# Следующая точка: 33.34912736600853x + -2.510269249589503
# Mean Squared Error: 1942.55
# ------------------------------------------------------------
# Итерация: 34
# Текущая точка: 33.34912736600853x + -2.510269249589503
# Следующая точка: 34.10466747430526x + -2.53945775745408
# Mean Squared Error: 1883.952
# ------------------------------------------------------------
# Итерация: 35
# Текущая точка: 34.10466747430526x + -2.53945775745408
# Следующая точка: 34.84795388007505x + -2.5667581515031297
# Mean Squared Error: 1827.248
# ------------------------------------------------------------
# Итерация: 36
# Текущая точка: 34.84795388007505x + -2.5667581515031297
# Следующая точка: 35.57918778335986x + -2.592228793675377
# Mean Squared Error: 1772.377
# ------------------------------------------------------------
# Итерация: 37
# Текущая точка: 35.57918778335986x + -2.592228793675377
# Следующая точка: 36.29856703294339x + -2.6159265511633976
# Mean Squared Error: 1719.277
# ------------------------------------------------------------
# Итерация: 38
# Текущая точка: 36.29856703294339x + -2.6159265511633976
# Следующая точка: 37.00628618308098x + -2.6379068315586593
# Mean Squared Error: 1667.892
# ------------------------------------------------------------
# Итерация: 39
# Текущая точка: 37.00628618308098x + -2.6379068315586593
# Следующая точка: 37.702536549252144x + -2.6582236172086455
# Mean Squared Error: 1618.165
# ------------------------------------------------------------
# Итерация: 40
# Текущая точка: 37.702536549252144x + -2.6582236172086455
# Следующая точка: 38.38750626295268x + -2.676929498803217
# Mean Squared Error: 1570.041
# ------------------------------------------------------------
# Итерация: 41
# Текущая точка: 38.38750626295268x + -2.676929498803217
# Следующая точка: 39.061380325543425x + -2.6940757082069964
# Mean Squared Error: 1523.469
# ------------------------------------------------------------
# Итерация: 42
# Текущая точка: 39.061380325543425x + -2.6940757082069964
# Следующая точка: 39.72434066117208x + -2.709712150554201
# Mean Squared Error: 1478.398
# ------------------------------------------------------------
# Итерация: 43
# Текущая точка: 39.72434066117208x + -2.709712150554201
# Следующая точка: 40.376566168784365x + -2.7238874356219984
# Mean Squared Error: 1434.779
# ------------------------------------------------------------
# Итерация: 44
# Текущая точка: 40.376566168784365x + -2.7238874356219984
# Следующая точка: 41.01823277324054x + -2.7366489084981254
# Mean Squared Error: 1392.565
# ------------------------------------------------------------
# Итерация: 45
# Текущая точка: 41.01823277324054x + -2.7366489084981254
# Следующая точка: 41.649513475552894x + -2.748042679558153
# Mean Squared Error: 1351.709
# ------------------------------------------------------------
# Итерация: 46
# Текущая точка: 41.649513475552894x + -2.748042679558153
# Следующая точка: 42.27057840225963x + -2.7581136537674795
# Mean Squared Error: 1312.168
# ------------------------------------------------------------
# Итерация: 47
# Текущая точка: 42.27057840225963x + -2.7581136537674795
# Следующая точка: 42.881594853950304x + -2.7669055593227827
# Mean Squared Error: 1273.898
# ------------------------------------------------------------
# Итерация: 48
# Текущая точка: 42.881594853950304x + -2.7669055593227827
# Следующая точка: 43.48272735295761x + -2.7744609756473717
# Mean Squared Error: 1236.859
# ------------------------------------------------------------
# Итерация: 49
# Текущая точка: 43.48272735295761x + -2.7744609756473717
# Следующая точка: 44.074137690230145x + -2.78082136075455
# Mean Squared Error: 1201.01
# ------------------------------------------------------------
# Итерация: 50
# Текущая точка: 44.074137690230145x + -2.78082136075455
# Следующая точка: 44.65598497140047x + -2.786027077992816
# Mean Squared Error: 1166.312
# ------------------------------------------------------------
# Итерация: 51
# Текущая точка: 44.65598497140047x + -2.786027077992816
# Следующая точка: 45.22842566206253x + -2.7901174221864156
# Mean Squared Error: 1132.729
# ------------------------------------------------------------
# Итерация: 52
# Текущая точка: 45.22842566206253x + -2.7901174221864156
# Следующая точка: 45.791613632272266x + -2.7931306451844855
# Mean Squared Error: 1100.223
# ------------------------------------------------------------
# Итерация: 53
# Текущая точка: 45.791613632272266x + -2.7931306451844855
# Следующая точка: 46.34570020028503x + -2.7951039808317333
# Mean Squared Error: 1068.761
# ------------------------------------------------------------
# Итерация: 54
# Текущая точка: 46.34570020028503x + -2.7951039808317333
# Следующая точка: 46.89083417554304x + -2.7960736693733277
# Mean Squared Error: 1038.307
# ------------------------------------------------------------
# Итерация: 55
# Текущая точка: 46.89083417554304x + -2.7960736693733277
# Следующая точка: 47.427161900926095x + -2.796074981306396
# Mean Squared Error: 1008.83
# ------------------------------------------------------------
# Итерация: 56
# Текущая точка: 47.427161900926095x + -2.796074981306396
# Следующая точка: 47.95482729427829x + -2.7951422406902666
# Mean Squared Error: 980.298
# ------------------------------------------------------------
# Итерация: 57
# Текущая точка: 47.95482729427829x + -2.7951422406902666
# Следующая точка: 48.473971889223506x + -2.7933088479273254
# Mean Squared Error: 952.679
# ------------------------------------------------------------
# Итерация: 58
# Текущая точка: 48.473971889223506x + -2.7933088479273254
# Следующая точка: 48.984734875281944x + -2.790607302026112
# Mean Squared Error: 925.945
# ------------------------------------------------------------
# Итерация: 59
# Текущая точка: 48.984734875281944x + -2.790607302026112
# Следующая точка: 49.48725313729999x + -2.7870692223580167
# Mean Squared Error: 900.067
# ------------------------------------------------------------
# Итерация: 60
# Текущая точка: 49.48725313729999x + -2.7870692223580167
# Следующая точка: 49.981661294205324x + -2.7827253699187096
# Mean Squared Error: 875.017
# ------------------------------------------------------------
# Итерация: 61
# Текущая точка: 49.981661294205324x + -2.7827253699187096
# Следующая точка: 50.468091737099115x + -2.777605668105185
# Mean Squared Error: 850.768
# ------------------------------------------------------------
# Итерация: 62
# Текущая точка: 50.468091737099115x + -2.777605668105185
# Следующая точка: 50.94667466669672x + -2.7717392230190754
# Mean Squared Error: 827.295
# ------------------------------------------------------------
# Итерация: 63
# Текущая точка: 50.94667466669672x + -2.7717392230190754
# Следующая точка: 51.41753813012839x + -2.765154343306658
# Mean Squared Error: 804.572
# ------------------------------------------------------------
# Итерация: 64
# Текущая точка: 51.41753813012839x + -2.765154343306658
# Следующая точка: 51.880808057111x + -2.75787855954575
# Mean Squared Error: 782.575
# ------------------------------------------------------------
# Итерация: 65
# Текущая точка: 51.880808057111x + -2.75787855954575
# Следующая точка: 52.33660829550179x + -2.7499386431894752
# Mean Squared Error: 761.28
# ------------------------------------------------------------
# Итерация: 66
# Текущая точка: 52.33660829550179x + -2.7499386431894752
# Следующая точка: 52.78506064624495x + -2.7413606250766698
# Mean Squared Error: 740.666
# ------------------------------------------------------------
# Итерация: 67
# Текущая точка: 52.78506064624495x + -2.7413606250766698
# Следующая точка: 53.22628489772146x + -2.732169813518474
# Mean Squared Error: 720.709
# ------------------------------------------------------------
# Итерация: 68
# Текущая точка: 53.22628489772146x + -2.732169813518474
# Следующая точка: 53.66039885951269x + -2.7223908119704685
# Mean Squared Error: 701.39
# ------------------------------------------------------------
# Итерация: 69
# Текущая точка: 53.66039885951269x + -2.7223908119704685
# Следующая точка: 54.087518395587864x + -2.712047536299493
# Mean Squared Error: 682.686
# ------------------------------------------------------------
# Итерация: 70
# Текущая точка: 54.087518395587864x + -2.712047536299493
# Следующая точка: 54.50775745692549x + -2.7011632316541077
# Mean Squared Error: 664.579
# ------------------------------------------------------------
# Итерация: 71
# Текущая точка: 54.50775745692549x + -2.7011632316541077
# Следующая точка: 54.92122811357847x + -2.6897604889474485
# Mean Squared Error: 647.049
# ------------------------------------------------------------
# Итерация: 72
# Текущая точка: 54.92122811357847x + -2.6897604889474485
# Следующая точка: 55.328040586192685x + -2.6778612609610457
# Mean Squared Error: 630.078
# ------------------------------------------------------------
# Итерация: 73
# Текущая точка: 55.328040586192685x + -2.6778612609610457
# Следующая точка: 55.7283032769884x + -2.6654868780779943
# Mean Squared Error: 613.647
# ------------------------------------------------------------
# Итерация: 74
# Текущая точка: 55.7283032769884x + -2.6654868780779943
# Следующая точка: 56.12212280021394x + -2.6526580636536723
# Mean Squared Error: 597.739
# ------------------------------------------------------------
# Итерация: 75
# Текущая точка: 56.12212280021394x + -2.6526580636536723
# Следующая точка: 56.50960401208069x + -2.639394949032039
# Mean Squared Error: 582.338
# ------------------------------------------------------------
# Итерация: 76
# Текущая точка: 56.50960401208069x + -2.639394949032039
# Следующая точка: 56.89085004018853x + -2.6257170882153638
# Mean Squared Error: 567.427
# ------------------------------------------------------------
# Итерация: 77
# Текущая точка: 56.89085004018853x + -2.6257170882153638
# Следующая точка: 57.26596231245036x + -2.611643472195066
# Mean Squared Error: 552.99
# ------------------------------------------------------------
# Итерация: 78
# Текущая точка: 57.26596231245036x + -2.611643472195066
# Следующая точка: 57.635040585524585x + -2.597192542951188
# Mean Squared Error: 539.012
# ------------------------------------------------------------
# Итерация: 79
# Текущая точка: 57.635040585524585x + -2.597192542951188
# Следующая точка: 57.998182972763985x + -2.5823822071278504
# Mean Squared Error: 525.478
# ------------------------------------------------------------
# Итерация: 80
# Текущая точка: 57.998182972763985x + -2.5823822071278504
# Следующая точка: 58.355485971689326x + -2.5672298493918886
# Mean Squared Error: 512.375
# ------------------------------------------------------------
# Итерация: 81
# Текущая точка: 58.355485971689326x + -2.5672298493918886
# Следующая точка: 58.70704449099603x + -2.5517523454817104
# Mean Squared Error: 499.688
# ------------------------------------------------------------
# Итерация: 82
# Текущая точка: 58.70704449099603x + -2.5517523454817104
# Следующая точка: 59.0529518771019x + -2.535966074953259
# Mean Squared Error: 487.404
# ------------------------------------------------------------
# Итерация: 83
# Текущая точка: 59.0529518771019x + -2.535966074953259
# Следующая точка: 59.39329994024382x + -2.519886933629823
# Mean Squared Error: 475.509
# ------------------------------------------------------------
# Итерация: 84
# Текущая точка: 59.39329994024382x + -2.519886933629823
# Следующая точка: 59.72817898013142x + -2.5035303457622837
# Mean Squared Error: 463.993
# ------------------------------------------------------------
# Итерация: 85
# Текущая точка: 59.72817898013142x + -2.5035303457622837
# Следующая точка: 60.057677811165064x + -2.4869112759062513
# Mean Squared Error: 452.841
# ------------------------------------------------------------
# Итерация: 86
# Текущая точка: 60.057677811165064x + -2.4869112759062513
# Следующая точка: 60.381883787225966x + -2.4700442405223964
# Mean Squared Error: 442.044
# ------------------------------------------------------------
# Итерация: 87
# Текущая точка: 60.381883787225966x + -2.4700442405223964
# Следующая точка: 60.700882826045664x + -2.452943319306151
# Mean Squared Error: 431.589
# ------------------------------------------------------------
# Итерация: 88
# Текущая точка: 60.700882826045664x + -2.452943319306151
# Следующая точка: 61.01475943316219x + -2.4356221662528235
# Mean Squared Error: 421.465
# ------------------------------------------------------------
# Итерация: 89
# Текущая точка: 61.01475943316219x + -2.4356221662528235
# Следующая точка: 61.32359672547002x + -2.4180940204640224
# Mean Squared Error: 411.662
# ------------------------------------------------------------
# Итерация: 90
# Текущая точка: 61.32359672547002x + -2.4180940204640224
# Следующая точка: 61.62747645437088x + -2.400371716701184
# Mean Squared Error: 402.17
# ------------------------------------------------------------
# Итерация: 91
# Текущая точка: 61.62747645437088x + -2.400371716701184
# Следующая точка: 61.92647902853224x + -2.3824676956918465
# Mean Squared Error: 392.978
# ------------------------------------------------------------
# Итерация: 92
# Текущая точка: 61.92647902853224x + -2.3824676956918465
# Следующая точка: 62.22068353626029x + -2.3643940141942066
# Mean Squared Error: 384.077
# ------------------------------------------------------------
# Итерация: 93
# Текущая точка: 62.22068353626029x + -2.3643940141942066
# Следующая точка: 62.510167767494x + -2.346162354825369
# Mean Squared Error: 375.458
# ------------------------------------------------------------
# Итерация: 94
# Текущая точка: 62.510167767494x + -2.346162354825369
# Следующая точка: 62.79500823542694x + -2.3277840356585835
# Mean Squared Error: 367.112
# ------------------------------------------------------------
# Итерация: 95
# Текущая точка: 62.79500823542694x + -2.3277840356585835
# Следующая точка: 63.075280197763014x + -2.3092700195946416
# Mean Squared Error: 359.03
# ------------------------------------------------------------
# Итерация: 96
# Текущая точка: 63.075280197763014x + -2.3092700195946416
# Следующая точка: 63.3510576776127x + -2.2906309235125097
# Mean Squared Error: 351.203
# ------------------------------------------------------------
# Итерация: 97
# Текущая точка: 63.3510576776127x + -2.2906309235125097
# Следующая точка: 63.622413484035796x + -2.2718770272041398
# Mean Squared Error: 343.624
# ------------------------------------------------------------
# Итерация: 98
# Текущая точка: 63.622413484035796x + -2.2718770272041398
# Следующая точка: 63.88941923223682x + -2.2530182820983167
# Mean Squared Error: 336.284
# ------------------------------------------------------------
# Итерация: 99
# Текущая точка: 63.88941923223682x + -2.2530182820983167
# Следующая точка: 64.15214536341904x + -2.2340643197782786
# Mean Squared Error: 329.176
# ------------------------------------------------------------
# Итерация: 100
# Текущая точка: 64.15214536341904x + -2.2340643197782786
# Следующая точка: 64.41066116430301x + -2.215024460297746
# Mean Squared Error: 322.293
# ------------------------------------------------------------
# Итерация: 101
# Текущая точка: 64.41066116430301x + -2.215024460297746
# Следующая точка: 64.66503478631539x + -2.1959077202999016
# Mean Squared Error: 315.627
# ------------------------------------------------------------
# Итерация: 102
# Текущая точка: 64.66503478631539x + -2.1959077202999016
# Следующая точка: 64.91533326445365x + -2.1767228209437577
# Mean Squared Error: 309.172
# ------------------------------------------------------------
# Итерация: 103
# Текущая точка: 64.91533326445365x + -2.1767228209437577
# Следующая точка: 65.16162253583235x + -2.1574781956422497
# Mean Squared Error: 302.92
# ------------------------------------------------------------
# Итерация: 104
# Текущая точка: 65.16162253583235x + -2.1574781956422497
# Следующая точка: 65.40396745791637x + -2.138181997616303
# Mean Squared Error: 296.866
# ------------------------------------------------------------
# Итерация: 105
# Текущая точка: 65.40396745791637x + -2.138181997616303
# Следующая точка: 65.64243182644644x + -2.118842107269028
# Mean Squared Error: 291.003
# ------------------------------------------------------------
# Итерация: 106
# Текущая точка: 65.64243182644644x + -2.118842107269028
# Следующая точка: 65.87707839306248x + -2.0994661393841083
# Mean Squared Error: 285.324
# ------------------------------------------------------------
# Итерация: 107
# Текущая точка: 65.87707839306248x + -2.0994661393841083
# Следующая точка: 66.1079688826295x + -2.080061450152346
# Mean Squared Error: 279.825
# ------------------------------------------------------------
# Итерация: 108
# Текущая точка: 66.1079688826295x + -2.080061450152346
# Следующая точка: 66.33516401027175x + -2.0606351440302646
# Mean Squared Error: 274.499
# ------------------------------------------------------------
# Итерация: 109
# Текущая точка: 66.33516401027175x + -2.0606351440302646
# Следующая точка: 66.55872349811946x + -2.041194080434561
# Mean Squared Error: 269.34
# ------------------------------------------------------------
# Итерация: 110
# Текущая точка: 66.55872349811946x + -2.041194080434561
# Следующая точка: 66.77870609177374x + -2.0217448802761293
# Mean Squared Error: 264.345
# ------------------------------------------------------------
# Итерация: 111
# Текущая точка: 66.77870609177374x + -2.0217448802761293
# Следующая точка: 66.99516957649399x + -2.002293932337292
# Mean Squared Error: 259.506
# ------------------------------------------------------------
# Итерация: 112
# Текущая точка: 66.99516957649399x + -2.002293932337292
# Следующая точка: 67.20817079311284x + -1.982847399495799
# Mean Squared Error: 254.82
# ------------------------------------------------------------
# Итерация: 113
# Текущая точка: 67.20817079311284x + -1.982847399495799
# Следующая точка: 67.41776565368319x + -1.9634112247990676
# Mean Squared Error: 250.282
# ------------------------------------------------------------
# Итерация: 114
# Текущая точка: 67.41776565368319x + -1.9634112247990676
# Следующая точка: 67.62400915686189x + -1.9439911373920735
# Mean Squared Error: 245.886
# ------------------------------------------------------------
# Итерация: 115
# Текущая точка: 67.62400915686189x + -1.9439911373920735
# Следующая точка: 67.82695540303476x + -1.9245926583022155
# Mean Squared Error: 241.629
# ------------------------------------------------------------
# Итерация: 116
# Текущая точка: 67.82695540303476x + -1.9245926583022155
# Следующая точка: 68.02665760918713x + -1.9052211060844115
# Mean Squared Error: 237.506
# ------------------------------------------------------------
# Итерация: 117
# Текущая точка: 68.02665760918713x + -1.9052211060844115
# Следующая точка: 68.22316812352443x + -1.8858816023296092
# Mean Squared Error: 233.512
# ------------------------------------------------------------
# Итерация: 118
# Текущая точка: 68.22316812352443x + -1.8858816023296092
# Следующая точка: 68.41653843984703x + -1.8665790770398243
# Mean Squared Error: 229.644
# ------------------------------------------------------------
# Итерация: 119
# Текущая точка: 68.41653843984703x + -1.8665790770398243
# Следующая точка: 68.60681921168357x + -1.8473182738727523
# Mean Squared Error: 225.897
# ------------------------------------------------------------
# Итерация: 120
# Текущая точка: 68.60681921168357x + -1.8473182738727523
# Следующая точка: 68.79406026618683x + -1.8281037552589305
# Mean Squared Error: 222.268
# ------------------------------------------------------------
# Итерация: 121
# Текущая точка: 68.79406026618683x + -1.8281037552589305
# Следующая точка: 68.97831061779635x + -1.8089399073943644
# Mean Squared Error: 218.754
# ------------------------------------------------------------
# Итерация: 122
# Текущая точка: 68.97831061779635x + -1.8089399073943644
# Следующая точка: 69.15961848167159x + -1.7898309451114642
# Mean Squared Error: 215.349
# ------------------------------------------------------------
# Итерация: 123
# Текущая точка: 69.15961848167159x + -1.7898309451114642
# Следующая точка: 69.33803128689966x + -1.7707809166310804
# Mean Squared Error: 212.052
# ------------------------------------------------------------
# Итерация: 124
# Текущая точка: 69.33803128689966x + -1.7707809166310804
# Следующая точка: 69.51359568948158x + -1.7517937081983594
# Mean Squared Error: 208.858
# ------------------------------------------------------------
# Итерация: 125
# Текущая точка: 69.51359568948158x + -1.7517937081983594
# Следующая точка: 69.6863575851005x + -1.7328730486050854
# Mean Squared Error: 205.764
# ------------------------------------------------------------
# Итерация: 126
# Текущая точка: 69.6863575851005x + -1.7328730486050854
# Следующая точка: 69.85636212167603x + -1.7140225136011105
# Mean Squared Error: 202.767
# ------------------------------------------------------------
# Итерация: 127
# Текущая точка: 69.85636212167603x + -1.7140225136011105
# Следующая точка: 70.02365371170801x + -1.6952455301974254
# Mean Squared Error: 199.865
# ------------------------------------------------------------
# Итерация: 128
# Текущая точка: 70.02365371170801x + -1.6952455301974254
# Следующая точка: 70.18827604441344x + -1.6765453808633568
# Mean Squared Error: 197.053
# ------------------------------------------------------------
# Итерация: 129
# Текущая точка: 70.18827604441344x + -1.6765453808633568
# Следующая точка: 70.35027209766008x + -1.6579252076203312
# Mean Squared Error: 194.33
# ------------------------------------------------------------
# Итерация: 130
# Текущая точка: 70.35027209766008x + -1.6579252076203312
# Следующая точка: 70.50968414970018x + -1.6393880160345868
# Mean Squared Error: 191.692
# ------------------------------------------------------------
# Итерация: 131
# Текущая точка: 70.50968414970018x + -1.6393880160345868
# Следующая точка: 70.66655379070772x + -1.6209366791111606
# Mean Squared Error: 189.137
# ------------------------------------------------------------
# Итерация: 132
# Текущая точка: 70.66655379070772x + -1.6209366791111606
# Следующая точка: 70.82092193412264x + -1.6025739410914317
# Mean Squared Error: 186.662
# ------------------------------------------------------------
# Итерация: 133
# Текущая точка: 70.82092193412264x + -1.6025739410914317
# Следующая точка: 70.97282882780499x + -1.5843024211564471
# Mean Squared Error: 184.264
# ------------------------------------------------------------
# Итерация: 134
# Текущая точка: 70.97282882780499x + -1.5843024211564471
# Следующая точка: 71.12231406500277x + -1.5661246170382073
# Mean Squared Error: 181.942
# ------------------------------------------------------------
# Итерация: 135
# Текущая точка: 71.12231406500277x + -1.5661246170382073
# Следующая точка: 71.26941659513614x + -1.5480429085410405
# Mean Squared Error: 179.692
# ------------------------------------------------------------
# Итерация: 136
# Текущая точка: 71.26941659513614x + -1.5480429085410405
# Следующая точка: 71.41417473440136x + -1.5300595609751526
# Mean Squared Error: 177.513
# ------------------------------------------------------------
# Итерация: 137
# Текущая точка: 71.41417473440136x + -1.5300595609751526
# Следующая точка: 71.55662617619754x + -1.5121767285043823
# Mean Squared Error: 175.402
# ------------------------------------------------------------
# Итерация: 138
# Текущая точка: 71.55662617619754x + -1.5121767285043823
# Следующая точка: 71.6968080013791x + -1.4943964574101574
# Mean Squared Error: 173.357
# ------------------------------------------------------------
# Итерация: 139
# Текущая точка: 71.6968080013791x + -1.4943964574101574
# Следующая точка: 71.83475668833698x + -1.4767206892735965
# Mean Squared Error: 171.376
# ------------------------------------------------------------
# Итерация: 140
# Текущая точка: 71.83475668833698x + -1.4767206892735965
# Следующая точка: 71.97050812291147x + -1.4591512640776598
# Mean Squared Error: 169.457
# ------------------------------------------------------------
# Итерация: 141
# Текущая точка: 71.97050812291147x + -1.4591512640776598
# Следующая точка: 72.10409760813954x + -1.4416899232312106
# Mean Squared Error: 167.598
# ------------------------------------------------------------
# Итерация: 142
# Текущая точка: 72.10409760813954x + -1.4416899232312106
# Следующая точка: 72.23555987383949x + -1.4243383125168056
# Mean Squared Error: 165.797
# ------------------------------------------------------------
# Итерация: 143
# Текущая точка: 72.23555987383949x + -1.4243383125168056
# Следующая точка: 72.36492908603564x + -1.4070979849639937
# Mean Squared Error: 164.053
# ------------------------------------------------------------
# Итерация: 144
# Текущая точка: 72.36492908603564x + -1.4070979849639937
# Следующая точка: 72.49223885622581x + -1.3899704036498624
# Mean Squared Error: 162.363
# ------------------------------------------------------------
# Итерация: 145
# Текущая точка: 72.49223885622581x + -1.3899704036498624
# Следующая точка: 72.61752225049422x + -1.3729569444285317
# Mean Squared Error: 160.725
# ------------------------------------------------------------
# Итерация: 146
# Текущая точка: 72.61752225049422x + -1.3729569444285317
# Следующая точка: 72.74081179847246x + -1.3560588985912592
# Mean Squared Error: 159.14
# ------------------------------------------------------------
# Итерация: 147
# Текущая точка: 72.74081179847246x + -1.3560588985912592
# Следующая точка: 72.86213950215117x + -1.3392774754587788
# Mean Squared Error: 157.603
# ------------------------------------------------------------
# Итерация: 148
# Текущая точка: 72.86213950215117x + -1.3392774754587788
# Следующая точка: 72.98153684454472x + -1.3226138049074656
# Mean Squared Error: 156.115
# ------------------------------------------------------------
# Итерация: 149
# Текущая точка: 72.98153684454472x + -1.3226138049074656
# Следующая точка: 73.09903479821173x + -1.306068939830876
# Mean Squared Error: 154.673
# ------------------------------------------------------------
# Итерация: 150
# Текущая точка: 73.09903479821173x + -1.306068939830876
# Следующая точка: 73.21466383363358x + -1.2896438585381858
# Mean Squared Error: 153.276
# ------------------------------------------------------------
# Итерация: 151
# Текущая точка: 73.21466383363358x + -1.2896438585381858
# Следующая точка: 73.32845392745342x + -1.2733394670910079
# Mean Squared Error: 151.923
# ------------------------------------------------------------
# Итерация: 152
# Текущая точка: 73.32845392745342x + -1.2733394670910079
# Следующая точка: 73.4404345705781x + -1.2571566015800413
# Mean Squared Error: 150.612
# ------------------------------------------------------------
# Итерация: 153
# Текущая точка: 73.4404345705781x + -1.2571566015800413
# Следующая точка: 73.55063477614522x + -1.2410960303429706
# Mean Squared Error: 149.342
# ------------------------------------------------------------
# Итерация: 154
# Текущая точка: 73.55063477614522x + -1.2410960303429706
# Следующая точка: 73.65908308735767x + -1.2251584561250022
# Mean Squared Error: 148.111
# ------------------------------------------------------------
# Итерация: 155
# Текущая точка: 73.65908308735767x + -1.2251584561250022
# Следующая точка: 73.76580758518787x + -1.2093445181833935
# Mean Squared Error: 146.919
# ------------------------------------------------------------
# Итерация: 156
# Текущая точка: 73.76580758518787x + -1.2093445181833935
# Следующая точка: 73.87083589595392x + -1.1936547943372993
# Mean Squared Error: 145.764
# ------------------------------------------------------------
# Итерация: 157
# Текущая точка: 73.87083589595392x + -1.1936547943372993
# Следующая точка: 73.97419519876976x + -1.1780898029642313
# Mean Squared Error: 144.645
# ------------------------------------------------------------
# Итерация: 158
# Текущая точка: 73.97419519876976x + -1.1780898029642313
# Следующая точка: 74.07591223287162x + -1.1626500049443966
# Mean Squared Error: 143.561
# ------------------------------------------------------------
# Итерация: 159
# Текущая точка: 74.07591223287162x + -1.1626500049443966
# Следующая точка: 74.17601330482263x + -1.1473358055541532
# Mean Squared Error: 142.511
# ------------------------------------------------------------
# Итерация: 160
# Текущая точка: 74.17601330482263x + -1.1473358055541532
# Следующая точка: 74.27452429559794x + -1.13214755630979
# Mean Squared Error: 141.494
# ------------------------------------------------------------
# Итерация: 161
# Текущая точка: 74.27452429559794x + -1.13214755630979
# Следующая точка: 74.371470667552x + -1.117085556762819
# Mean Squared Error: 140.508
# ------------------------------------------------------------
# Итерация: 162
# Текущая точка: 74.371470667552x + -1.117085556762819
# Следующая точка: 74.46687747127034x + -1.1021500562479285
# Mean Squared Error: 139.553
# ------------------------------------------------------------
# Итерация: 163
# Текущая точка: 74.46687747127034x + -1.1021500562479285
# Следующая точка: 74.56076935230753x + -1.0873412555847317
# Mean Squared Error: 138.628
# ------------------------------------------------------------
# Итерация: 164
# Текущая точка: 74.56076935230753x + -1.0873412555847317
# Следующая точка: 74.65317055781348x + -1.0726593087344134
# Mean Squared Error: 137.732
# ------------------------------------------------------------
# Итерация: 165
# Текущая точка: 74.65317055781348x + -1.0726593087344134
# Следующая точка: 74.74410494304966x + -1.0581043244123536
# Mean Squared Error: 136.863
# ------------------------------------------------------------
# Итерация: 166
# Текущая точка: 74.74410494304966x + -1.0581043244123536
# Следующая точка: 74.83359597779744x + -1.0436763676577827
# Mean Squared Error: 136.022
# ------------------------------------------------------------
# Итерация: 167
# Текущая точка: 74.83359597779744x + -1.0436763676577827
# Следующая точка: 74.92166675266006x + -1.0293754613614985
# Mean Squared Error: 135.206
# ------------------------------------------------------------
# Итерация: 168
# Текущая точка: 74.92166675266006x + -1.0293754613614985
# Следующая точка: 75.0083399852602x + -1.0152015877526535
# Mean Squared Error: 134.416
# ------------------------------------------------------------
# Итерация: 169
# Текущая точка: 75.0083399852602x + -1.0152015877526535
# Следующая точка: 75.09363802633497x + -1.0011546898455959
# Mean Squared Error: 133.651
# ------------------------------------------------------------
# Итерация: 170
# Текущая точка: 75.09363802633497x + -1.0011546898455959
# Следующая точка: 75.1775828657297x + -0.9872346728477275
# Mean Squared Error: 132.91
# ------------------------------------------------------------
# Итерация: 171
# Текущая точка: 75.1775828657297x + -0.9872346728477275
# Следующая точка: 75.26019613829274x + -0.9734414055293168
# Mean Squared Error: 132.191
# ------------------------------------------------------------
# Итерация: 172
# Текущая точка: 75.26019613829274x + -0.9734414055293168
# Следующая точка: 75.34149912967246x + -0.9597747215561885
# Mean Squared Error: 131.495
# ------------------------------------------------------------
# Итерация: 173
# Текущая точка: 75.34149912967246x + -0.9597747215561885
# Следующая точка: 75.4215127820184x + -0.9462344207861848
# Mean Squared Error: 130.821
# ------------------------------------------------------------
# Итерация: 174
# Текущая точка: 75.4215127820184x + -0.9462344207861848
# Следующая точка: 75.50025769958806x + -0.9328202705302786
# Mean Squared Error: 130.168
# ------------------------------------------------------------
# Итерация: 175
# Текущая точка: 75.50025769958806x + -0.9328202705302786
# Следующая точка: 75.57775415426097x + -0.9195320067791937
# Mean Squared Error: 129.535
# ------------------------------------------------------------
# Итерация: 176
# Текущая точка: 75.57775415426097x + -0.9195320067791937
# Следующая точка: 75.65402209096148x + -0.9063693353963711
# Mean Squared Error: 128.921
# ------------------------------------------------------------
# Итерация: 177
# Текущая точка: 75.65402209096148x + -0.9063693353963711
# Следующая точка: 75.72908113299198x + -0.8933319332781001
# Mean Squared Error: 128.327
# ------------------------------------------------------------
# Итерация: 178
# Текущая точка: 75.72908113299198x + -0.8933319332781001
# Следующая точка: 75.80295058727792x + -0.8804194494816132
# Mean Squared Error: 127.751
# ------------------------------------------------------------
# Итерация: 179
# Текущая точка: 75.80295058727792x + -0.8804194494816132
# Следующая точка: 75.87564944952612x + -0.8676315063219279
# Mean Squared Error: 127.193
# ------------------------------------------------------------
# Итерация: 180
# Текущая точка: 75.87564944952612x + -0.8676315063219279
# Следующая точка: 75.94719640929796x + -0.8549677004381976
# Mean Squared Error: 126.652
# ------------------------------------------------------------
# Итерация: 181
# Текущая точка: 75.94719640929796x + -0.8549677004381976
# Следующая точка: 76.01760985499865x + -0.8424276038303197
# Mean Squared Error: 126.129
# ------------------------------------------------------------
# Итерация: 182
# Текущая точка: 76.01760985499865x + -0.8424276038303197
# Следующая точка: 76.08690787878419x + -0.830010764866528
# Mean Squared Error: 125.621
# ------------------------------------------------------------
# Итерация: 183
# Текущая точка: 76.08690787878419x + -0.830010764866528
# Следующая точка: 76.15510828138729x + -0.8177167092626838
# Mean Squared Error: 125.129
# ------------------------------------------------------------
# Итерация: 184
# Текущая точка: 76.15510828138729x + -0.8177167092626838
# Следующая точка: 76.22222857686367x + -0.80554494103396
# Mean Squared Error: 124.653
# ------------------------------------------------------------
# Итерация: 185
# Текущая точка: 76.22222857686367x + -0.80554494103396
# Следующая точка: 76.28828599726002x + -0.7934949434195993
# Mean Squared Error: 124.191
# ------------------------------------------------------------
# Итерация: 186
# Текущая точка: 76.28828599726002x + -0.7934949434195993
# Следующая точка: 76.35329749720496x + -0.7815661797814103
# Mean Squared Error: 123.744
# ------------------------------------------------------------
# Итерация: 187
# Текущая точка: 76.35329749720496x + -0.7815661797814103
# Следующая точка: 76.41727975842429x + -0.7697580944766514
# Mean Squared Error: 123.31
# ------------------------------------------------------------
# Итерация: 188
# Текущая точка: 76.41727975842429x + -0.7697580944766514
# Следующая точка: 76.48024919418178x + -0.758070113705935
# Mean Squared Error: 122.89
# ------------------------------------------------------------
# Итерация: 189
# Текущая точка: 76.48024919418178x + -0.758070113705935
# Следующая точка: 76.5422219536468x + -0.746501646336773
# Mean Squared Error: 122.483
# ------------------------------------------------------------
# Итерация: 190
# Текущая точка: 76.5422219536468x + -0.746501646336773
# Следующая точка: 76.60321392618991x + -0.7350520847033677
# Mean Squared Error: 122.089
# ------------------------------------------------------------
# Итерация: 191
# Текущая точка: 76.60321392618991x + -0.7350520847033677
# Следующая точка: 76.66324074560772x + -0.7237208053832404
# Mean Squared Error: 121.707
# ------------------------------------------------------------
# Итерация: 192
# Текущая точка: 76.66324074560772x + -0.7237208053832404
# Следующая точка: 76.7223177942782x + -0.712507169951273
# Mean Squared Error: 121.337
# ------------------------------------------------------------
# Итерация: 193
# Текущая точка: 76.7223177942782x + -0.712507169951273
# Следующая точка: 76.78046020724743x + -0.701410525711729
# Mean Squared Error: 120.978
# ------------------------------------------------------------
# Итерация: 194
# Текущая точка: 76.78046020724743x + -0.701410525711729
# Следующая точка: 76.83768287624923x + -0.6904302064088037
# Mean Squared Error: 120.63
# ------------------------------------------------------------
# Итерация: 195
# Текущая точка: 76.83768287624923x + -0.6904302064088037
# Следующая точка: 76.89400045365853x + -0.6795655329162412
# Mean Squared Error: 120.294
# ------------------------------------------------------------
# Итерация: 196
# Текущая точка: 76.89400045365853x + -0.6795655329162412
# Следующая точка: 76.94942735637972x + -0.6688158139065459
# Mean Squared Error: 119.967
# ------------------------------------------------------------
# Итерация: 197
# Текущая точка: 76.94942735637972x + -0.6688158139065459
# Следующая точка: 77.003977769671x + -0.6581803465002988
# Mean Squared Error: 119.651
# ------------------------------------------------------------
# Итерация: 198
# Текущая точка: 77.003977769671x + -0.6581803465002988
# Следующая точка: 77.05766565090592x + -0.6476584168960836
# Mean Squared Error: 119.344
# ------------------------------------------------------------
# Итерация: 199
# Текущая точка: 77.05766565090592x + -0.6476584168960836
# Следующая точка: 77.11050473327295x + -0.6372493009815096
# Mean Squared Error: 119.047
# ------------------------------------------------------------
# Итерация: 200
# Текущая точка: 77.11050473327295x + -0.6372493009815096
# Следующая точка: 77.16250852941431x + -0.6269522649258107
# Mean Squared Error: 118.76
# ------------------------------------------------------------
# Итерация: 201
# Текущая точка: 77.16250852941431x + -0.6269522649258107
# Следующая точка: 77.213690335005x + -0.6167665657544883
# Mean Squared Error: 118.481
# ------------------------------------------------------------
# Итерация: 202
# Текущая точка: 77.213690335005x + -0.6167665657544883
# Следующая точка: 77.26406323227296x + -0.6066914519064537
# Mean Squared Error: 118.211
# ------------------------------------------------------------
# Итерация: 203
# Текущая точка: 77.26406323227296x + -0.6066914519064537
# Следующая точка: 77.3136400934615x + -0.596726163774115
# Mean Squared Error: 117.949
# ------------------------------------------------------------
# Итерация: 204
# Текущая точка: 77.3136400934615x + -0.596726163774115
# Следующая точка: 77.36243358423476x + -0.586869934226845
# Mean Squared Error: 117.695
# ------------------------------------------------------------
# Итерация: 205
# Текущая точка: 77.36243358423476x + -0.586869934226845
# Следующая точка: 77.41045616702736x + -0.5771219891182539
# Mean Squared Error: 117.449
# ------------------------------------------------------------
# Итерация: 206
# Текущая точка: 77.41045616702736x + -0.5771219891182539
# Следующая точка: 77.45772010433897x + -0.5674815477776819
# Mean Squared Error: 117.211
# ------------------------------------------------------------
# Итерация: 207
# Текущая точка: 77.45772010433897x + -0.5674815477776819
# Следующая точка: 77.50423746197491x + -0.5579478234863174
# Mean Squared Error: 116.98
# ------------------------------------------------------------
# Итерация: 208
# Текущая точка: 77.50423746197491x + -0.5579478234863174
# Следующая точка: 77.55002011223347x + -0.5485200239383362
# Mean Squared Error: 116.756
# ------------------------------------------------------------
# Итерация: 209
# Текущая точка: 77.55002011223347x + -0.5485200239383362
# Следующая точка: 77.59507973704106x + -0.5391973516874469
# Mean Squared Error: 116.54
# ------------------------------------------------------------
# Итерация: 210
# Текущая точка: 77.59507973704106x + -0.5391973516874469
# Следующая точка: 77.63942783103587x + -0.5299790045792218
# Mean Squared Error: 116.329
# ------------------------------------------------------------
# Итерация: 211
# Текущая точка: 77.63942783103587x + -0.5299790045792218
# Следующая точка: 77.68307570460102x + -0.5208641761695798
# Mean Squared Error: 116.126
# ------------------------------------------------------------
# Итерация: 212
# Текущая точка: 77.68307570460102x + -0.5208641761695798
# Следующая точка: 77.72603448684792x + -0.5118520561297819
# Mean Squared Error: 115.929
# ------------------------------------------------------------
# Итерация: 213
# Текущая точка: 77.72603448684792x + -0.5118520561297819
# Следующая точка: 77.76831512855084x + -0.5029418306382891
# Mean Squared Error: 115.737
# ------------------------------------------------------------
# Итерация: 214
# Текущая точка: 77.76831512855084x + -0.5029418306382891
# Следующая точка: 77.8099284050333x + -0.4941326827598276
# Mean Squared Error: 115.552
# ------------------------------------------------------------
# Итерация: 215
# Текущая точка: 77.8099284050333x + -0.4941326827598276
# Следующая точка: 77.8508849190073x + -0.4854237928119931
# Mean Squared Error: 115.373
# ------------------------------------------------------------
# Итерация: 216
# Текущая точка: 77.8508849190073x + -0.4854237928119931
# Следующая точка: 77.89119510336592x + -0.47681433871972356
# Mean Squared Error: 115.199
# ------------------------------------------------------------
# Итерация: 217
# Текущая точка: 77.89119510336592x + -0.47681433871972356
# Следующая точка: 77.93086922393029x + -0.4683034963579573
# Mean Squared Error: 115.03
# ------------------------------------------------------------
# Итерация: 218
# Текущая точка: 77.93086922393029x + -0.4683034963579573
# Следующая точка: 77.96991738215156x + -0.45989043988278855
# Mean Squared Error: 114.867
# ------------------------------------------------------------
# Итерация: 219
# Текущая точка: 77.96991738215156x + -0.45989043988278855
# Следующая точка: 78.0083495177687x + -0.4515743420514243
# Mean Squared Error: 114.708
# ------------------------------------------------------------
# Итерация: 220
# Текущая точка: 78.0083495177687x + -0.4515743420514243
# Следующая точка: 78.04617541142272x + -0.4433543745312392
# Mean Squared Error: 114.555
# ------------------------------------------------------------
# Итерация: 221
# Текущая точка: 78.04617541142272x + -0.4433543745312392
# Следующая точка: 78.08340468722825x + -0.4352297081982171
# Mean Squared Error: 114.406
# ------------------------------------------------------------
# Итерация: 222
# Текущая точка: 78.08340468722825x + -0.4352297081982171
# Следующая точка: 78.12004681530296x + -0.4271995134250629
# Mean Squared Error: 114.262
# ------------------------------------------------------------
# Итерация: 223
# ...
# Итерация: 821
# Текущая точка: 80.41842344755018x + 0.18163715859229448
# Следующая точка: 80.41842653696594x + 0.1816384124178918
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 822
# Текущая точка: 80.41842653696594x + 0.1816384124178918
# Следующая точка: 80.41842957866753x + 0.18163964703896066
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 823
# Текущая точка: 80.41842957866753x + 0.18163964703896066
# Следующая точка: 80.41843257339214x + 0.18164086274896515
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 824
# Текущая точка: 80.41843257339214x + 0.18164086274896515
# Следующая точка: 80.41843552186558x + 0.18164205983689904
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 825
# Текущая точка: 80.41843552186558x + 0.18164205983689904
# Следующая точка: 80.41843842480243x + 0.18164323858735346
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 826
# Текущая точка: 80.41843842480243x + 0.18164323858735346
# Следующая точка: 80.41844128290623x + 0.18164439928058382
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 827
# Текущая точка: 80.41844128290623x + 0.18164439928058382
# Следующая точка: 80.41844409686962x + 0.18164554219257562
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 828
# Текущая точка: 80.41844409686962x + 0.18164554219257562
# Следующая точка: 80.41844686737457x + 0.18164666759510908
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 829
# Текущая точка: 80.41844686737457x + 0.18164666759510908
# Следующая точка: 80.4184495950925x + 0.181647775755823
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 830
# Текущая точка: 80.4184495950925x + 0.181647775755823
# Следующая точка: 80.41845228068442x + 0.18164886693827773
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 831
# Текущая точка: 80.41845228068442x + 0.18164886693827773
# Следующая точка: 80.41845492480117x + 0.18164994140201696
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 832
# Текущая точка: 80.41845492480117x + 0.18164994140201696
# Следующая точка: 80.4184575280835x + 0.18165099940262866
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 833
# Текущая точка: 80.4184575280835x + 0.18165099940262866
# Следующая точка: 80.41846009116225x + 0.18165204119180514
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 834
# Текущая точка: 80.41846009116225x + 0.18165204119180514
# Следующая точка: 80.41846261465852x + 0.1816530670174023
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 835
# Текущая точка: 80.41846261465852x + 0.1816530670174023
# Следующая точка: 80.41846509918385x + 0.1816540771234977
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 836
# Текущая точка: 80.41846509918385x + 0.1816540771234977
# Следующая точка: 80.41846754534026x + 0.18165507175044812
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 837
# Текущая точка: 80.41846754534026x + 0.18165507175044812
# Следующая точка: 80.4184699537205x + 0.1816560511349459
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 838
# Текущая точка: 80.4184699537205x + 0.1816560511349459
# Следующая точка: 80.41847232490817x + 0.18165701551007452
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 839
# Текущая точка: 80.41847232490817x + 0.18165701551007452
# Следующая точка: 80.41847465947781x + 0.1816579651053637
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 840
# Текущая точка: 80.41847465947781x + 0.1816579651053637
# Следующая точка: 80.41847695799513x + 0.18165890014684305
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 841
# Текущая точка: 80.41847695799513x + 0.18165890014684305
# Следующая точка: 80.41847922101705x + 0.18165982085709545
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 842
# Текущая точка: 80.41847922101705x + 0.18165982085709545
# Следующая точка: 80.41848144909193x + 0.18166072745530937
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 843
# Текущая точка: 80.41848144909193x + 0.18166072745530937
# Следующая точка: 80.41848364275961x + 0.18166162015733034
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 844
# Текущая точка: 80.41848364275961x + 0.18166162015733034
# Следующая точка: 80.41848580255161x + 0.18166249917571184
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 845
# Текущая точка: 80.41848580255161x + 0.18166249917571184
# Следующая точка: 80.41848792899124x + 0.18166336471976524
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 846
# Текущая точка: 80.41848792899124x + 0.18166336471976524
# Следующая точка: 80.4184900225937x + 0.1816642169956092
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 847
# Текущая точка: 80.4184900225937x + 0.1816642169956092
# Следующая точка: 80.41849208386625x + 0.18166505620621795
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 848
# Текущая точка: 80.41849208386625x + 0.18166505620621795
# Следующая точка: 80.41849411330831x + 0.1816658825514694
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 849
# Текущая точка: 80.41849411330831x + 0.1816658825514694
# Следующая точка: 80.41849611141157x + 0.18166669622819182
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 850
# Текущая точка: 80.41849611141157x + 0.18166669622819182
# Следующая точка: 80.41849807866012x + 0.1816674974302106
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 851
# Текущая точка: 80.41849807866012x + 0.1816674974302106
# Следующая точка: 80.41850001553058x + 0.1816682863483936
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 852
# Текущая точка: 80.41850001553058x + 0.1816682863483936
# Следующая точка: 80.41850192249221x + 0.18166906317069617
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 853
# Текущая точка: 80.41850192249221x + 0.18166906317069617
# Следующая точка: 80.418503800007x + 0.18166982808220555
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 854
# Текущая точка: 80.418503800007x + 0.18166982808220555
# Следующая точка: 80.4185056485298x + 0.18167058126518437
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 855
# Текущая точка: 80.4185056485298x + 0.18167058126518437
# Следующая точка: 80.41850746850845x + 0.18167132289911364
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 856
# Текущая точка: 80.41850746850845x + 0.18167132289911364
# Следующая точка: 80.41850926038386x + 0.18167205316073495
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 857
# Текущая точка: 80.41850926038386x + 0.18167205316073495
# Следующая точка: 80.41851102459012x + 0.18167277222409242
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 858
# Текущая точка: 80.41851102459012x + 0.18167277222409242
# Следующая точка: 80.41851276155461x + 0.18167348026057337
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 859
# Текущая точка: 80.41851276155461x + 0.18167348026057337
# Следующая точка: 80.41851447169812x + 0.18167417743894887
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 860
# Текущая точка: 80.41851447169812x + 0.18167417743894887
# Следующая точка: 80.41851615543493x + 0.1816748639254136
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 861
# Текущая точка: 80.41851615543493x + 0.1816748639254136
# Следующая точка: 80.41851781317293x + 0.18167553988362503
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 862
# Текущая точка: 80.41851781317293x + 0.18167553988362503
# Следующая точка: 80.41851944531369x + 0.18167620547474195
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 863
# Текущая точка: 80.41851944531369x + 0.18167620547474195
# Следующая точка: 80.41852105225259x + 0.18167686085746262
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 864
# Текущая точка: 80.41852105225259x + 0.18167686085746262
# Следующая точка: 80.41852263437887x + 0.181677506188062
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 865
# Текущая точка: 80.41852263437887x + 0.181677506188062
# Следующая точка: 80.4185241920758x + 0.18167814162042883
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 866
# Текущая точка: 80.4185241920758x + 0.18167814162042883
# Следующая точка: 80.41852572572068x + 0.18167876730610183
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 867
# Текущая точка: 80.41852572572068x + 0.18167876730610183
# Следующая точка: 80.41852723568503x + 0.18167938339430545
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 868
# Текущая точка: 80.41852723568503x + 0.18167938339430545
# Следующая точка: 80.41852872233459x + 0.18167999003198512
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 869
# Текущая точка: 80.41852872233459x + 0.18167999003198512
# Следующая точка: 80.41853018602946x + 0.18168058736384204
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 870
# Текущая точка: 80.41853018602946x + 0.18168058736384204
# Следующая точка: 80.4185316271242x + 0.18168117553236723
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 871
# Текущая точка: 80.4185316271242x + 0.18168117553236723
# Следующая точка: 80.41853304596785x + 0.18168175467787526
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 872
# Текущая точка: 80.41853304596785x + 0.18168175467787526
# Следующая точка: 80.41853444290408x + 0.18168232493853714
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 873
# Текущая точка: 80.41853444290408x + 0.18168232493853714
# Следующая точка: 80.41853581827125x + 0.18168288645041342
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 874
# Текущая точка: 80.41853581827125x + 0.18168288645041342
# Следующая точка: 80.4185371724025x + 0.18168343934748585
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 875
# Текущая точка: 80.4185371724025x + 0.18168343934748585
# Следующая точка: 80.4185385056258x + 0.18168398376168932
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 876
# Текущая точка: 80.4185385056258x + 0.18168398376168932
# Следующая точка: 80.41853981826408x + 0.18168451982294287
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 877
# Текущая точка: 80.41853981826408x + 0.18168451982294287
# Следующая точка: 80.41854111063525x + 0.18168504765918067
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 878
# Текущая точка: 80.41854111063525x + 0.18168504765918067
# Следующая точка: 80.41854238305233x + 0.18168556739638175
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 879
# Текущая точка: 80.41854238305233x + 0.18168556739638175
# Следующая точка: 80.4185436358235x + 0.18168607915860038
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 880
# Текущая точка: 80.4185436358235x + 0.18168607915860038
# Следующая точка: 80.41854486925216x + 0.18168658306799498
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 881
# Текущая точка: 80.41854486925216x + 0.18168658306799498
# Следующая точка: 80.41854608363705x + 0.181687079244857
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 882
# Текущая точка: 80.41854608363705x + 0.181687079244857
# Следующая точка: 80.4185472792723x + 0.18168756780763964
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 883
# Текущая точка: 80.4185472792723x + 0.18168756780763964
# Следующая точка: 80.41854845644747x + 0.18168804887298556
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 884
# Текущая точка: 80.41854845644747x + 0.18168804887298556
# Следующая точка: 80.41854961544763x + 0.18168852255575477
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 885
# Текущая точка: 80.41854961544763x + 0.18168852255575477
# Следующая точка: 80.4185507565535x + 0.18168898896905142
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 886
# Текущая точка: 80.4185507565535x + 0.18168898896905142
# Следующая точка: 80.41855188004142x + 0.1816894482242509
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 887
# Текущая точка: 80.41855188004142x + 0.1816894482242509
# Следующая точка: 80.41855298618349x + 0.18168990043102606
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 888
# Текущая точка: 80.41855298618349x + 0.18168990043102606
# Следующая точка: 80.41855407524757x + 0.18169034569737305
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 889
# Текущая точка: 80.41855407524757x + 0.18169034569737305
# Следующая точка: 80.41855514749741x + 0.181690784129637
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 890
# Текущая точка: 80.41855514749741x + 0.181690784129637
# Следующая точка: 80.4185562031927x + 0.18169121583253717
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 891
# Текущая точка: 80.4185562031927x + 0.18169121583253717
# Следующая точка: 80.41855724258906x + 0.1816916409091917
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 892
# Текущая точка: 80.41855724258906x + 0.1816916409091917
# Следующая точка: 80.41855826593822x + 0.18169205946114214
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 893
# Текущая точка: 80.41855826593822x + 0.18169205946114214
# Следующая точка: 80.41855927348799x + 0.18169247158837717
# Mean Squared Error: 109.736
# ------------------------------------------------------------
# Итерация: 894
# Текущая точка: 80.41855927348799x + 0.18169247158837717
# Следующая точка: 80.41856026548236x + 0.18169287738935666
# Mean Squared Error: 109.736
# ------------------------------------------------------------

# %%
x_feature = np.arange(-3, 3)

model_y_our = next_w1*x_feature + next_w0

fig = plt.figure(figsize = (10, 6))
plt.plot(x_feature, model_y_sklearn, linewidth = 4, color = 'r')
plt.plot(x_feature, model_y_our, '--', linewidth = 2,color = 'b')
plt.plot()
plt.xlabel('Feature')
plt.ylabel('Target')
plt.scatter(X, y)
plt.show()
print(f'Линейная модель sklearn вида: {sklearn_a}x + {sklearn_b}')
print(f'Наша линейная модель вида: {next_w1}x + {next_w0}')
# Out:
# Линейная модель sklearn вида: 80.41862353979872x + 0.1817188754210104
# Наша линейная модель вида: 80.41856026548236x + 0.18169287738935666

# %% [markdown]
# Многомерная регрессия

# %%
from sklearn.datasets import make_regression

X, y, coefficients = make_regression (n_samples = 50, n_features= 3,  n_informative = 3, noise = 10, coef = True,random_state = 11)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X, y)

print(model.coef_ , model.intercept_)
sklearn_a =  model.coef_
sklearn_b = model.intercept_
# Out:
# [16.03610262 26.27272897 95.12674829] -0.47032859908297375

# %%
X.shape
count_weights = X.shape[1]
X
# Out:
# array([[-1.06560298, -0.47573349, -0.88623967],
#        [-2.65331856, -0.31963136, -0.00828463],
#        [-1.29742262,  0.51447963, -0.71496244],
#        [ 0.76616062, -0.26434233, -0.99402769],
#        [-0.64257539, -0.57395456, -0.17809318],
#        [-0.42442882,  1.65920462, -0.1329099 ],
#        [-0.03107509,  1.0956297 , -0.68344663],
#        [ 0.85866717,  1.11487028, -1.26407368],
#        [-0.43205762,  0.45539286,  0.51608404],
#        [ 2.20185631,  1.93290543, -0.0370669 ],
#        [-0.53662936,  0.42105072,  0.31540267],
#        [-0.96420485,  0.2716063 ,  0.07175977],
#        [ 0.43477699,  0.0716521 ,  0.87427277],
#        [-0.17241977,  1.06755846,  0.09183837],
#        [ 0.25771638,  0.50502192, -0.49673048],
#        [ 1.29561858, -1.23234621, -0.23725045],
#        [-0.52937203, -1.08019383,  1.56170369],
#        [ 0.03679475,  1.7915311 , -0.04870254],
#        [-1.06163445,  0.1178195 ,  0.21734821],
#        [-1.63905163,  0.81776957, -0.64730263],
#        [ 1.74945474, -0.48456513, -0.286073  ],
#        [-0.08940364,  0.15072201,  0.68212971],
#        [-0.20437532, -0.18577532, -0.4864951 ],
#        [-0.38053642,  0.06367166,  0.08897764],
#        [-0.52308763,  1.29127473, -0.25127692],
#        [-1.57749431, -0.79286501,  1.31094364],
#        [ 1.01594215, -0.68280162,  0.59527845],
#        [ 0.83031043, -0.13054147, -0.86335252],
#        [-0.71355993,  0.68731235, -1.90828954],
#        [-1.11947526,  1.57463407,  0.73683739],
#        [-1.82300958,  1.84636487,  0.8791138 ],
#        [ 0.63007982,  0.73227135,  0.07349324],
#        [-0.30957664,  1.54907163,  0.72575222],
#        [ 0.29634711, -1.54686257,  1.40277112],
#        [-1.0616544 , -0.47621448, -0.68448467],
#        [-1.53214252,  0.18566325,  0.21886858],
#        [-0.8430661 ,  0.38535414, -0.14189358],
#        [ 0.69556726,  0.53382172,  1.08771086],
#        [-0.47748923, -1.55107946, -0.15406552],
#        [ 0.5936862 ,  1.34537807,  0.37050633],
#        [ 0.37864068,  0.15384125, -0.46456606],
#        [-0.26196107,  0.51655239,  0.57897111],
#        [ 1.54220922, -0.04480262,  0.85615205],
#        [-1.99357153,  0.86705521, -2.04905726],
#        [ 0.68968231, -1.30554851,  0.56119218],
#        [ 1.83277654,  0.01699688, -1.1288944 ],
#        [-0.07174941, -0.82943725,  2.15667443],
#        [-1.68411089,  0.60010201, -1.18575527],
#        [ 0.39521201,  1.20910164,  0.12286753],
#        [ 0.94303598,  0.13827322,  0.34115344]])

# %%
X = np.column_stack([X, np.ones((X.shape[0]))])
X
# Out:
# array([[-1.06560298, -0.47573349, -0.88623967,  1.        ],
#        [-2.65331856, -0.31963136, -0.00828463,  1.        ],
#        [-1.29742262,  0.51447963, -0.71496244,  1.        ],
#        [ 0.76616062, -0.26434233, -0.99402769,  1.        ],
#        [-0.64257539, -0.57395456, -0.17809318,  1.        ],
#        [-0.42442882,  1.65920462, -0.1329099 ,  1.        ],
#        [-0.03107509,  1.0956297 , -0.68344663,  1.        ],
#        [ 0.85866717,  1.11487028, -1.26407368,  1.        ],
#        [-0.43205762,  0.45539286,  0.51608404,  1.        ],
#        [ 2.20185631,  1.93290543, -0.0370669 ,  1.        ],
#        [-0.53662936,  0.42105072,  0.31540267,  1.        ],
#        [-0.96420485,  0.2716063 ,  0.07175977,  1.        ],
#        [ 0.43477699,  0.0716521 ,  0.87427277,  1.        ],
#        [-0.17241977,  1.06755846,  0.09183837,  1.        ],
#        [ 0.25771638,  0.50502192, -0.49673048,  1.        ],
#        [ 1.29561858, -1.23234621, -0.23725045,  1.        ],
#        [-0.52937203, -1.08019383,  1.56170369,  1.        ],
#        [ 0.03679475,  1.7915311 , -0.04870254,  1.        ],
#        [-1.06163445,  0.1178195 ,  0.21734821,  1.        ],
#        [-1.63905163,  0.81776957, -0.64730263,  1.        ],
#        [ 1.74945474, -0.48456513, -0.286073  ,  1.        ],
#        [-0.08940364,  0.15072201,  0.68212971,  1.        ],
#        [-0.20437532, -0.18577532, -0.4864951 ,  1.        ],
#        [-0.38053642,  0.06367166,  0.08897764,  1.        ],
#        [-0.52308763,  1.29127473, -0.25127692,  1.        ],
#        [-1.57749431, -0.79286501,  1.31094364,  1.        ],
#        [ 1.01594215, -0.68280162,  0.59527845,  1.        ],
#        [ 0.83031043, -0.13054147, -0.86335252,  1.        ],
#        [-0.71355993,  0.68731235, -1.90828954,  1.        ],
#        [-1.11947526,  1.57463407,  0.73683739,  1.        ],
#        [-1.82300958,  1.84636487,  0.8791138 ,  1.        ],
#        [ 0.63007982,  0.73227135,  0.07349324,  1.        ],
#        [-0.30957664,  1.54907163,  0.72575222,  1.        ],
#        [ 0.29634711, -1.54686257,  1.40277112,  1.        ],
#        [-1.0616544 , -0.47621448, -0.68448467,  1.        ],
#        [-1.53214252,  0.18566325,  0.21886858,  1.        ],
#        [-0.8430661 ,  0.38535414, -0.14189358,  1.        ],
#        [ 0.69556726,  0.53382172,  1.08771086,  1.        ],
#        [-0.47748923, -1.55107946, -0.15406552,  1.        ],
#        [ 0.5936862 ,  1.34537807,  0.37050633,  1.        ],
#        [ 0.37864068,  0.15384125, -0.46456606,  1.        ],
#        [-0.26196107,  0.51655239,  0.57897111,  1.        ],
#        [ 1.54220922, -0.04480262,  0.85615205,  1.        ],
#        [-1.99357153,  0.86705521, -2.04905726,  1.        ],
#        [ 0.68968231, -1.30554851,  0.56119218,  1.        ],
#        [ 1.83277654,  0.01699688, -1.1288944 ,  1.        ],
#        [-0.07174941, -0.82943725,  2.15667443,  1.        ],
#        [-1.68411089,  0.60010201, -1.18575527,  1.        ],
#        [ 0.39521201,  1.20910164,  0.12286753,  1.        ],
#        [ 0.94303598,  0.13827322,  0.34115344,  1.        ]])

# %%
def MSE(X, w, y):
    y_pred = X@w
    return np.sum( (y-y_pred)**2 / (len(y_pred)+1)) 

def MSE_grad(X, w, y):
    y_pred = X@w
    return 2/(len(X)+1) *(y - y_pred )@(-X)

# %%
weights = np.zeros((count_weights+1))

learning_rate = 0.01

next_weights = weights

max_iterations = 10000
eps = 10**(-3)
it = 1
while (it <= max_iterations):
    cur_weights = next_weights
    
    next_weights =  cur_weights - learning_rate * MSE_grad(X, cur_weights, y)
    
    print(f'Итерация: {it}')
    print(f'Mean Squared Error: {round(MSE(X, cur_weights, y), 3)}')
    it+=1
    if np.linalg.norm(cur_weights - next_weights, ord = 2) <= eps:
        break
# Out:
# Итерация: 1
# Mean Squared Error: 6554.436
# Итерация: 2
# Mean Squared Error: 6379.119
# Итерация: 3
# Mean Squared Error: 6208.932
# Итерация: 4
# Mean Squared Error: 6043.712
# Итерация: 5
# Mean Squared Error: 5883.301
# Итерация: 6
# Mean Squared Error: 5727.547
# Итерация: 7
# Mean Squared Error: 5576.302
# Итерация: 8
# Mean Squared Error: 5429.426
# Итерация: 9
# Mean Squared Error: 5286.781
# Итерация: 10
# Mean Squared Error: 5148.234
# Итерация: 11
# Mean Squared Error: 5013.659
# Итерация: 12
# Mean Squared Error: 4882.931
# Итерация: 13
# Mean Squared Error: 4755.932
# Итерация: 14
# Mean Squared Error: 4632.546
# Итерация: 15
# Mean Squared Error: 4512.662
# Итерация: 16
# Mean Squared Error: 4396.173
# Итерация: 17
# Mean Squared Error: 4282.975
# Итерация: 18
# Mean Squared Error: 4172.967
# Итерация: 19
# Mean Squared Error: 4066.053
# Итерация: 20
# Mean Squared Error: 3962.138
# Итерация: 21
# Mean Squared Error: 3861.132
# Итерация: 22
# Mean Squared Error: 3762.946
# Итерация: 23
# Mean Squared Error: 3667.498
# Итерация: 24
# Mean Squared Error: 3574.703
# Итерация: 25
# Mean Squared Error: 3484.483
# Итерация: 26
# Mean Squared Error: 3396.761
# Итерация: 27
# Mean Squared Error: 3311.462
# Итерация: 28
# Mean Squared Error: 3228.515
# Итерация: 29
# Mean Squared Error: 3147.851
# Итерация: 30
# Mean Squared Error: 3069.401
# Итерация: 31
# Mean Squared Error: 2993.1
# Итерация: 32
# Mean Squared Error: 2918.886
# Итерация: 33
# Mean Squared Error: 2846.697
# Итерация: 34
# Mean Squared Error: 2776.474
# Итерация: 35
# Mean Squared Error: 2708.16
# Итерация: 36
# Mean Squared Error: 2641.7
# Итерация: 37
# Mean Squared Error: 2577.039
# Итерация: 38
# Mean Squared Error: 2514.125
# Итерация: 39
# Mean Squared Error: 2452.908
# Итерация: 40
# Mean Squared Error: 2393.34
# Итерация: 41
# Mean Squared Error: 2335.372
# Итерация: 42
# Mean Squared Error: 2278.959
# Итерация: 43
# Mean Squared Error: 2224.057
# Итерация: 44
# Mean Squared Error: 2170.622
# Итерация: 45
# Mean Squared Error: 2118.612
# Итерация: 46
# Mean Squared Error: 2067.988
# Итерация: 47
# Mean Squared Error: 2018.709
# Итерация: 48
# Mean Squared Error: 1970.738
# Итерация: 49
# Mean Squared Error: 1924.038
# Итерация: 50
# Mean Squared Error: 1878.573
# Итерация: 51
# Mean Squared Error: 1834.308
# Итерация: 52
# Mean Squared Error: 1791.21
# Итерация: 53
# Mean Squared Error: 1749.246
# Итерация: 54
# Mean Squared Error: 1708.384
# Итерация: 55
# Mean Squared Error: 1668.594
# Итерация: 56
# Mean Squared Error: 1629.846
# Итерация: 57
# Mean Squared Error: 1592.111
# Итерация: 58
# Mean Squared Error: 1555.36
# Итерация: 59
# Mean Squared Error: 1519.567
# Итерация: 60
# Mean Squared Error: 1484.706
# Итерация: 61
# Mean Squared Error: 1450.75
# Итерация: 62
# Mean Squared Error: 1417.674
# Итерация: 63
# Mean Squared Error: 1385.455
# Итерация: 64
# Mean Squared Error: 1354.069
# Итерация: 65
# Mean Squared Error: 1323.494
# Итерация: 66
# Mean Squared Error: 1293.706
# Итерация: 67
# Mean Squared Error: 1264.685
# Итерация: 68
# Mean Squared Error: 1236.411
# Итерация: 69
# Mean Squared Error: 1208.861
# Итерация: 70
# Mean Squared Error: 1182.018
# Итерация: 71
# Mean Squared Error: 1155.862
# Итерация: 72
# Mean Squared Error: 1130.374
# Итерация: 73
# Mean Squared Error: 1105.536
# Итерация: 74
# Mean Squared Error: 1081.331
# Итерация: 75
# Mean Squared Error: 1057.742
# Итерация: 76
# Mean Squared Error: 1034.752
# Итерация: 77
# Mean Squared Error: 1012.346
# Итерация: 78
# Mean Squared Error: 990.507
# Итерация: 79
# Mean Squared Error: 969.221
# Итерация: 80
# Mean Squared Error: 948.473
# Итерация: 81
# Mean Squared Error: 928.249
# Итерация: 82
# Mean Squared Error: 908.534
# Итерация: 83
# Mean Squared Error: 889.315
# Итерация: 84
# Mean Squared Error: 870.58
# Итерация: 85
# Mean Squared Error: 852.314
# Итерация: 86
# Mean Squared Error: 834.507
# Итерация: 87
# Mean Squared Error: 817.145
# Итерация: 88
# Mean Squared Error: 800.218
# Итерация: 89
# Mean Squared Error: 783.713
# Итерация: 90
# Mean Squared Error: 767.62
# Итерация: 91
# Mean Squared Error: 751.928
# Итерация: 92
# Mean Squared Error: 736.626
# Итерация: 93
# Mean Squared Error: 721.705
# Итерация: 94
# Mean Squared Error: 707.153
# Итерация: 95
# Mean Squared Error: 692.963
# Итерация: 96
# Mean Squared Error: 679.124
# Итерация: 97
# Mean Squared Error: 665.627
# Итерация: 98
# Mean Squared Error: 652.463
# Итерация: 99
# Mean Squared Error: 639.624
# Итерация: 100
# Mean Squared Error: 627.102
# Итерация: 101
# Mean Squared Error: 614.887
# Итерация: 102
# Mean Squared Error: 602.973
# Итерация: 103
# Mean Squared Error: 591.352
# Итерация: 104
# Mean Squared Error: 580.015
# Итерация: 105
# Mean Squared Error: 568.956
# Итерация: 106
# Mean Squared Error: 558.168
# Итерация: 107
# Mean Squared Error: 547.643
# Итерация: 108
# Mean Squared Error: 537.376
# Итерация: 109
# Mean Squared Error: 527.359
# Итерация: 110
# Mean Squared Error: 517.585
# Итерация: 111
# Mean Squared Error: 508.05
# Итерация: 112
# Mean Squared Error: 498.747
# Итерация: 113
# Mean Squared Error: 489.669
# Итерация: 114
# Mean Squared Error: 480.811
# Итерация: 115
# Mean Squared Error: 472.168
# Итерация: 116
# Mean Squared Error: 463.735
# Итерация: 117
# Mean Squared Error: 455.505
# Итерация: 118
# Mean Squared Error: 447.474
# Итерация: 119
# Mean Squared Error: 439.636
# Итерация: 120
# Mean Squared Error: 431.988
# Итерация: 121
# Mean Squared Error: 424.524
# Итерация: 122
# Mean Squared Error: 417.239
# Итерация: 123
# Mean Squared Error: 410.129
# Итерация: 124
# Mean Squared Error: 403.19
# Итерация: 125
# Mean Squared Error: 396.418
# Итерация: 126
# Mean Squared Error: 389.807
# Итерация: 127
# Mean Squared Error: 383.355
# Итерация: 128
# Mean Squared Error: 377.057
# Итерация: 129
# Mean Squared Error: 370.91
# Итерация: 130
# Mean Squared Error: 364.909
# Итерация: 131
# Mean Squared Error: 359.051
# Итерация: 132
# Mean Squared Error: 353.333
# Итерация: 133
# Mean Squared Error: 347.75
# Итерация: 134
# Mean Squared Error: 342.301
# Итерация: 135
# Mean Squared Error: 336.981
# Итерация: 136
# Mean Squared Error: 331.787
# Итерация: 137
# Mean Squared Error: 326.716
# Итерация: 138
# Mean Squared Error: 321.765
# Итерация: 139
# Mean Squared Error: 316.932
# Итерация: 140
# Mean Squared Error: 312.212
# Итерация: 141
# Mean Squared Error: 307.605
# Итерация: 142
# Mean Squared Error: 303.105
# Итерация: 143
# Mean Squared Error: 298.712
# Итерация: 144
# Mean Squared Error: 294.423
# Итерация: 145
# Mean Squared Error: 290.234
# Итерация: 146
# Mean Squared Error: 286.144
# Итерация: 147
# Mean Squared Error: 282.15
# Итерация: 148
# Mean Squared Error: 278.249
# Итерация: 149
# Mean Squared Error: 274.441
# Итерация: 150
# Mean Squared Error: 270.721
# Итерация: 151
# Mean Squared Error: 267.088
# Итерация: 152
# Mean Squared Error: 263.541
# Итерация: 153
# Mean Squared Error: 260.076
# Итерация: 154
# Mean Squared Error: 256.692
# Итерация: 155
# Mean Squared Error: 253.388
# Итерация: 156
# Mean Squared Error: 250.16
# Итерация: 157
# Mean Squared Error: 247.007
# Итерация: 158
# Mean Squared Error: 243.928
# Итерация: 159
# Mean Squared Error: 240.921
# Итерация: 160
# Mean Squared Error: 237.983
# Итерация: 161
# Mean Squared Error: 235.114
# Итерация: 162
# Mean Squared Error: 232.311
# Итерация: 163
# Mean Squared Error: 229.573
# Итерация: 164
# Mean Squared Error: 226.898
# Итерация: 165
# Mean Squared Error: 224.286
# Итерация: 166
# Mean Squared Error: 221.734
# Итерация: 167
# Mean Squared Error: 219.241
# Итерация: 168
# Mean Squared Error: 216.805
# Итерация: 169
# Mean Squared Error: 214.426
# Итерация: 170
# Mean Squared Error: 212.101
# Итерация: 171
# Mean Squared Error: 209.83
# Итерация: 172
# Mean Squared Error: 207.612
# Итерация: 173
# Mean Squared Error: 205.444
# Итерация: 174
# Mean Squared Error: 203.326
# Итерация: 175
# Mean Squared Error: 201.257
# Итерация: 176
# Mean Squared Error: 199.236
# Итерация: 177
# Mean Squared Error: 197.261
# Итерация: 178
# Mean Squared Error: 195.331
# Итерация: 179
# Mean Squared Error: 193.445
# Итерация: 180
# Mean Squared Error: 191.603
# Итерация: 181
# Mean Squared Error: 189.802
# Итерация: 182
# Mean Squared Error: 188.043
# Итерация: 183
# Mean Squared Error: 186.324
# Итерация: 184
# Mean Squared Error: 184.645
# Итерация: 185
# Mean Squared Error: 183.003
# Итерация: 186
# Mean Squared Error: 181.399
# Итерация: 187
# Mean Squared Error: 179.832
# Итерация: 188
# Mean Squared Error: 178.3
# Итерация: 189
# Mean Squared Error: 176.803
# Итерация: 190
# Mean Squared Error: 175.341
# Итерация: 191
# Mean Squared Error: 173.911
# Итерация: 192
# Mean Squared Error: 172.514
# Итерация: 193
# Mean Squared Error: 171.149
# Итерация: 194
# Mean Squared Error: 169.814
# Итерация: 195
# Mean Squared Error: 168.51
# Итерация: 196
# Mean Squared Error: 167.236
# Итерация: 197
# Mean Squared Error: 165.99
# Итерация: 198
# Mean Squared Error: 164.772
# Итерация: 199
# Mean Squared Error: 163.582
# Итерация: 200
# Mean Squared Error: 162.419
# Итерация: 201
# Mean Squared Error: 161.282
# Итерация: 202
# Mean Squared Error: 160.171
# Итерация: 203
# Mean Squared Error: 159.085
# Итерация: 204
# Mean Squared Error: 158.024
# Итерация: 205
# Mean Squared Error: 156.986
# Итерация: 206
# Mean Squared Error: 155.972
# Итерация: 207
# Mean Squared Error: 154.98
# Итерация: 208
# Mean Squared Error: 154.011
# Итерация: 209
# Mean Squared Error: 153.064
# Итерация: 210
# Mean Squared Error: 152.138
# Итерация: 211
# Mean Squared Error: 151.232
# Итерация: 212
# Mean Squared Error: 150.348
# Итерация: 213
# Mean Squared Error: 149.482
# Итерация: 214
# Mean Squared Error: 148.637
# Итерация: 215
# Mean Squared Error: 147.81
# Итерация: 216
# Mean Squared Error: 147.002
# Итерация: 217
# Mean Squared Error: 146.212
# Итерация: 218
# Mean Squared Error: 145.439
# Итерация: 219
# Mean Squared Error: 144.684
# Итерация: 220
# Mean Squared Error: 143.946
# Итерация: 221
# Mean Squared Error: 143.224
# Итерация: 222
# Mean Squared Error: 142.519
# Итерация: 223
# Mean Squared Error: 141.829
# Итерация: 224
# Mean Squared Error: 141.154
# Итерация: 225
# Mean Squared Error: 140.495
# Итерация: 226
# Mean Squared Error: 139.85
# Итерация: 227
# Mean Squared Error: 139.22
# Итерация: 228
# Mean Squared Error: 138.603
# Итерация: 229
# Mean Squared Error: 138.0
# Итерация: 230
# Mean Squared Error: 137.411
# Итерация: 231
# Mean Squared Error: 136.835
# Итерация: 232
# Mean Squared Error: 136.272
# Итерация: 233
# Mean Squared Error: 135.721
# Итерация: 234
# Mean Squared Error: 135.182
# Итерация: 235
# Mean Squared Error: 134.656
# Итерация: 236
# Mean Squared Error: 134.141
# Итерация: 237
# Mean Squared Error: 133.637
# Итерация: 238
# Mean Squared Error: 133.145
# Итерация: 239
# Mean Squared Error: 132.663
# Итерация: 240
# Mean Squared Error: 132.193
# Итерация: 241
# Mean Squared Error: 131.732
# Итерация: 242
# Mean Squared Error: 131.282
# Итерация: 243
# Mean Squared Error: 130.842
# Итерация: 244
# Mean Squared Error: 130.411
# Итерация: 245
# Mean Squared Error: 129.99
# Итерация: 246
# Mean Squared Error: 129.579
# Итерация: 247
# Mean Squared Error: 129.176
# Итерация: 248
# Mean Squared Error: 128.782
# Итерация: 249
# Mean Squared Error: 128.397
# Итерация: 250
# Mean Squared Error: 128.021
# Итерация: 251
# Mean Squared Error: 127.652
# Итерация: 252
# Mean Squared Error: 127.292
# Итерация: 253
# Mean Squared Error: 126.94
# Итерация: 254
# Mean Squared Error: 126.596
# Итерация: 255
# Mean Squared Error: 126.259
# Итерация: 256
# Mean Squared Error: 125.929
# Итерация: 257
# Mean Squared Error: 125.607
# Итерация: 258
# Mean Squared Error: 125.292
# Итерация: 259
# Mean Squared Error: 124.984
# Итерация: 260
# Mean Squared Error: 124.683
# Итерация: 261
# Mean Squared Error: 124.388
# Итерация: 262
# Mean Squared Error: 124.099
# Итерация: 263
# Mean Squared Error: 123.817
# Итерация: 264
# Mean Squared Error: 123.542
# Итерация: 265
# Mean Squared Error: 123.272
# Итерация: 266
# Mean Squared Error: 123.008
# Итерация: 267
# Mean Squared Error: 122.75
# Итерация: 268
# Mean Squared Error: 122.497
# Итерация: 269
# Mean Squared Error: 122.251
# Итерация: 270
# Mean Squared Error: 122.009
# Итерация: 271
# Mean Squared Error: 121.773
# Итерация: 272
# Mean Squared Error: 121.542
# Итерация: 273
# Mean Squared Error: 121.316
# Итерация: 274
# Mean Squared Error: 121.095
# Итерация: 275
# Mean Squared Error: 120.879
# Итерация: 276
# Mean Squared Error: 120.667
# Итерация: 277
# Mean Squared Error: 120.46
# Итерация: 278
# Mean Squared Error: 120.258
# Итерация: 279
# Mean Squared Error: 120.06
# Итерация: 280
# Mean Squared Error: 119.866
# Итерация: 281
# Mean Squared Error: 119.677
# Итерация: 282
# Mean Squared Error: 119.492
# Итерация: 283
# Mean Squared Error: 119.31
# Итерация: 284
# Mean Squared Error: 119.133
# Итерация: 285
# Mean Squared Error: 118.96
# Итерация: 286
# Mean Squared Error: 118.79
# Итерация: 287
# Mean Squared Error: 118.624
# Итерация: 288
# Mean Squared Error: 118.462
# Итерация: 289
# Mean Squared Error: 118.303
# Итерация: 290
# Mean Squared Error: 118.148
# Итерация: 291
# Mean Squared Error: 117.996
# Итерация: 292
# Mean Squared Error: 117.847
# Итерация: 293
# Mean Squared Error: 117.702
# Итерация: 294
# Mean Squared Error: 117.559
# Итерация: 295
# Mean Squared Error: 117.42
# Итерация: 296
# Mean Squared Error: 117.284
# Итерация: 297
# Mean Squared Error: 117.151
# Итерация: 298
# Mean Squared Error: 117.021
# Итерация: 299
# Mean Squared Error: 116.893
# Итерация: 300
# Mean Squared Error: 116.768
# Итерация: 301
# Mean Squared Error: 116.646
# Итерация: 302
# Mean Squared Error: 116.527
# Итерация: 303
# Mean Squared Error: 116.41
# Итерация: 304
# Mean Squared Error: 116.296
# Итерация: 305
# Mean Squared Error: 116.184
# Итерация: 306
# Mean Squared Error: 116.075
# Итерация: 307
# Mean Squared Error: 115.968
# Итерация: 308
# Mean Squared Error: 115.863
# Итерация: 309
# Mean Squared Error: 115.761
# Итерация: 310
# Mean Squared Error: 115.661
# Итерация: 311
# Mean Squared Error: 115.563
# Итерация: 312
# Mean Squared Error: 115.467
# Итерация: 313
# Mean Squared Error: 115.373
# Итерация: 314
# Mean Squared Error: 115.281
# Итерация: 315
# Mean Squared Error: 115.191
# Итерация: 316
# Mean Squared Error: 115.104
# Итерация: 317
# Mean Squared Error: 115.018
# Итерация: 318
# Mean Squared Error: 114.934
# Итерация: 319
# Mean Squared Error: 114.851
# Итерация: 320
# Mean Squared Error: 114.771
# Итерация: 321
# Mean Squared Error: 114.692
# Итерация: 322
# Mean Squared Error: 114.615
# Итерация: 323
# Mean Squared Error: 114.539
# Итерация: 324
# Mean Squared Error: 114.466
# Итерация: 325
# Mean Squared Error: 114.394
# Итерация: 326
# Mean Squared Error: 114.323
# Итерация: 327
# Mean Squared Error: 114.254
# Итерация: 328
# Mean Squared Error: 114.186
# Итерация: 329
# Mean Squared Error: 114.12
# Итерация: 330
# Mean Squared Error: 114.055
# Итерация: 331
# Mean Squared Error: 113.992
# Итерация: 332
# Mean Squared Error: 113.93
# Итерация: 333
# Mean Squared Error: 113.869
# Итерация: 334
# Mean Squared Error: 113.81
# Итерация: 335
# Mean Squared Error: 113.752
# Итерация: 336
# Mean Squared Error: 113.695
# Итерация: 337
# Mean Squared Error: 113.64
# Итерация: 338
# Mean Squared Error: 113.585
# Итерация: 339
# Mean Squared Error: 113.532
# Итерация: 340
# Mean Squared Error: 113.48
# Итерация: 341
# Mean Squared Error: 113.429
# Итерация: 342
# Mean Squared Error: 113.379
# Итерация: 343
# Mean Squared Error: 113.33
# Итерация: 344
# Mean Squared Error: 113.282
# Итерация: 345
# Mean Squared Error: 113.236
# Итерация: 346
# Mean Squared Error: 113.19
# Итерация: 347
# Mean Squared Error: 113.145
# Итерация: 348
# Mean Squared Error: 113.102
# Итерация: 349
# Mean Squared Error: 113.059
# Итерация: 350
# Mean Squared Error: 113.017
# Итерация: 351
# Mean Squared Error: 112.976
# Итерация: 352
# Mean Squared Error: 112.936
# Итерация: 353
# Mean Squared Error: 112.896
# Итерация: 354
# Mean Squared Error: 112.858
# Итерация: 355
# Mean Squared Error: 112.82
# Итерация: 356
# Mean Squared Error: 112.784
# Итерация: 357
# Mean Squared Error: 112.748
# Итерация: 358
# Mean Squared Error: 112.712
# Итерация: 359
# Mean Squared Error: 112.678
# Итерация: 360
# Mean Squared Error: 112.644
# Итерация: 361
# Mean Squared Error: 112.611
# Итерация: 362
# Mean Squared Error: 112.579
# Итерация: 363
# Mean Squared Error: 112.547
# Итерация: 364
# Mean Squared Error: 112.516
# Итерация: 365
# Mean Squared Error: 112.486
# Итерация: 366
# Mean Squared Error: 112.456
# Итерация: 367
# Mean Squared Error: 112.427
# Итерация: 368
# Mean Squared Error: 112.399
# Итерация: 369
# Mean Squared Error: 112.371
# Итерация: 370
# Mean Squared Error: 112.344
# Итерация: 371
# Mean Squared Error: 112.318
# Итерация: 372
# Mean Squared Error: 112.292
# Итерация: 373
# Mean Squared Error: 112.266
# Итерация: 374
# Mean Squared Error: 112.241
# Итерация: 375
# Mean Squared Error: 112.217
# Итерация: 376
# Mean Squared Error: 112.193
# Итерация: 377
# Mean Squared Error: 112.17
# Итерация: 378
# Mean Squared Error: 112.147
# Итерация: 379
# Mean Squared Error: 112.124
# Итерация: 380
# Mean Squared Error: 112.102
# Итерация: 381
# Mean Squared Error: 112.081
# Итерация: 382
# Mean Squared Error: 112.06
# Итерация: 383
# Mean Squared Error: 112.04
# Итерация: 384
# Mean Squared Error: 112.02
# Итерация: 385
# Mean Squared Error: 112.0
# Итерация: 386
# Mean Squared Error: 111.981
# Итерация: 387
# Mean Squared Error: 111.962
# Итерация: 388
# Mean Squared Error: 111.943
# Итерация: 389
# Mean Squared Error: 111.925
# Итерация: 390
# Mean Squared Error: 111.908
# Итерация: 391
# Mean Squared Error: 111.891
# Итерация: 392
# Mean Squared Error: 111.874
# Итерация: 393
# Mean Squared Error: 111.857
# Итерация: 394
# Mean Squared Error: 111.841
# Итерация: 395
# Mean Squared Error: 111.825
# Итерация: 396
# Mean Squared Error: 111.81
# Итерация: 397
# Mean Squared Error: 111.794
# Итерация: 398
# Mean Squared Error: 111.78
# Итерация: 399
# Mean Squared Error: 111.765
# Итерация: 400
# Mean Squared Error: 111.751
# Итерация: 401
# Mean Squared Error: 111.737
# Итерация: 402
# Mean Squared Error: 111.723
# Итерация: 403
# Mean Squared Error: 111.71
# Итерация: 404
# Mean Squared Error: 111.697
# Итерация: 405
# Mean Squared Error: 111.684
# Итерация: 406
# Mean Squared Error: 111.672
# Итерация: 407
# Mean Squared Error: 111.66
# Итерация: 408
# Mean Squared Error: 111.648
# Итерация: 409
# Mean Squared Error: 111.636
# Итерация: 410
# Mean Squared Error: 111.624
# Итерация: 411
# Mean Squared Error: 111.613
# Итерация: 412
# Mean Squared Error: 111.602
# Итерация: 413
# Mean Squared Error: 111.591
# Итерация: 414
# Mean Squared Error: 111.581
# Итерация: 415
# Mean Squared Error: 111.571
# Итерация: 416
# Mean Squared Error: 111.561
# Итерация: 417
# Mean Squared Error: 111.551
# Итерация: 418
# Mean Squared Error: 111.541
# Итерация: 419
# Mean Squared Error: 111.532
# Итерация: 420
# Mean Squared Error: 111.522
# Итерация: 421
# Mean Squared Error: 111.513
# Итерация: 422
# Mean Squared Error: 111.505
# Итерация: 423
# Mean Squared Error: 111.496
# Итерация: 424
# Mean Squared Error: 111.487
# Итерация: 425
# Mean Squared Error: 111.479
# Итерация: 426
# Mean Squared Error: 111.471
# Итерация: 427
# Mean Squared Error: 111.463
# Итерация: 428
# Mean Squared Error: 111.455
# Итерация: 429
# Mean Squared Error: 111.448
# Итерация: 430
# Mean Squared Error: 111.44
# Итерация: 431
# Mean Squared Error: 111.433
# Итерация: 432
# Mean Squared Error: 111.426
# Итерация: 433
# Mean Squared Error: 111.419
# Итерация: 434
# Mean Squared Error: 111.412
# Итерация: 435
# Mean Squared Error: 111.405
# Итерация: 436
# Mean Squared Error: 111.399
# Итерация: 437
# Mean Squared Error: 111.392
# Итерация: 438
# Mean Squared Error: 111.386
# Итерация: 439
# Mean Squared Error: 111.38
# Итерация: 440
# Mean Squared Error: 111.374
# Итерация: 441
# Mean Squared Error: 111.368
# Итерация: 442
# Mean Squared Error: 111.362
# Итерация: 443
# Mean Squared Error: 111.357
# Итерация: 444
# Mean Squared Error: 111.351
# Итерация: 445
# Mean Squared Error: 111.346
# Итерация: 446
# Mean Squared Error: 111.341
# Итерация: 447
# Mean Squared Error: 111.335
# Итерация: 448
# Mean Squared Error: 111.33
# Итерация: 449
# Mean Squared Error: 111.325
# Итерация: 450
# Mean Squared Error: 111.32
# Итерация: 451
# Mean Squared Error: 111.316
# Итерация: 452
# Mean Squared Error: 111.311
# Итерация: 453
# Mean Squared Error: 111.307
# Итерация: 454
# Mean Squared Error: 111.302
# Итерация: 455
# Mean Squared Error: 111.298
# Итерация: 456
# Mean Squared Error: 111.294
# Итерация: 457
# Mean Squared Error: 111.289
# Итерация: 458
# Mean Squared Error: 111.285
# Итерация: 459
# Mean Squared Error: 111.281
# Итерация: 460
# Mean Squared Error: 111.277
# Итерация: 461
# Mean Squared Error: 111.274
# Итерация: 462
# Mean Squared Error: 111.27
# Итерация: 463
# Mean Squared Error: 111.266
# Итерация: 464
# Mean Squared Error: 111.263
# Итерация: 465
# Mean Squared Error: 111.259
# Итерация: 466
# Mean Squared Error: 111.256
# Итерация: 467
# Mean Squared Error: 111.252
# Итерация: 468
# Mean Squared Error: 111.249
# Итерация: 469
# Mean Squared Error: 111.246
# Итерация: 470
# Mean Squared Error: 111.243
# Итерация: 471
# Mean Squared Error: 111.239
# Итерация: 472
# Mean Squared Error: 111.236
# Итерация: 473
# Mean Squared Error: 111.233
# Итерация: 474
# Mean Squared Error: 111.231
# Итерация: 475
# Mean Squared Error: 111.228
# Итерация: 476
# Mean Squared Error: 111.225
# Итерация: 477
# Mean Squared Error: 111.222
# Итерация: 478
# Mean Squared Error: 111.22
# Итерация: 479
# Mean Squared Error: 111.217
# Итерация: 480
# Mean Squared Error: 111.214
# Итерация: 481
# Mean Squared Error: 111.212
# Итерация: 482
# Mean Squared Error: 111.21
# Итерация: 483
# Mean Squared Error: 111.207
# Итерация: 484
# Mean Squared Error: 111.205
# Итерация: 485
# Mean Squared Error: 111.203
# Итерация: 486
# Mean Squared Error: 111.2
# Итерация: 487
# Mean Squared Error: 111.198
# Итерация: 488
# Mean Squared Error: 111.196
# Итерация: 489
# Mean Squared Error: 111.194
# Итерация: 490
# Mean Squared Error: 111.192
# Итерация: 491
# Mean Squared Error: 111.19
# Итерация: 492
# Mean Squared Error: 111.188
# Итерация: 493
# Mean Squared Error: 111.186
# Итерация: 494
# Mean Squared Error: 111.184
# Итерация: 495
# Mean Squared Error: 111.182
# Итерация: 496
# Mean Squared Error: 111.18
# Итерация: 497
# Mean Squared Error: 111.179
# Итерация: 498
# Mean Squared Error: 111.177
# Итерация: 499
# Mean Squared Error: 111.175
# Итерация: 500
# Mean Squared Error: 111.173
# Итерация: 501
# Mean Squared Error: 111.172
# Итерация: 502
# Mean Squared Error: 111.17
# Итерация: 503
# Mean Squared Error: 111.169
# Итерация: 504
# Mean Squared Error: 111.167
# Итерация: 505
# Mean Squared Error: 111.166
# Итерация: 506
# Mean Squared Error: 111.164
# Итерация: 507
# Mean Squared Error: 111.163
# Итерация: 508
# Mean Squared Error: 111.161
# Итерация: 509
# Mean Squared Error: 111.16
# Итерация: 510
# Mean Squared Error: 111.159
# Итерация: 511
# Mean Squared Error: 111.157
# Итерация: 512
# Mean Squared Error: 111.156
# Итерация: 513
# Mean Squared Error: 111.155
# Итерация: 514
# Mean Squared Error: 111.154
# Итерация: 515
# Mean Squared Error: 111.152
# Итерация: 516
# Mean Squared Error: 111.151
# Итерация: 517
# Mean Squared Error: 111.15
# Итерация: 518
# Mean Squared Error: 111.149
# Итерация: 519
# Mean Squared Error: 111.148
# Итерация: 520
# Mean Squared Error: 111.147
# Итерация: 521
# Mean Squared Error: 111.146
# Итерация: 522
# Mean Squared Error: 111.145
# Итерация: 523
# Mean Squared Error: 111.144
# Итерация: 524
# Mean Squared Error: 111.143
# Итерация: 525
# Mean Squared Error: 111.142
# Итерация: 526
# Mean Squared Error: 111.141
# Итерация: 527
# Mean Squared Error: 111.14
# Итерация: 528
# Mean Squared Error: 111.139
# Итерация: 529
# Mean Squared Error: 111.138
# Итерация: 530
# Mean Squared Error: 111.137
# Итерация: 531
# Mean Squared Error: 111.136
# Итерация: 532
# Mean Squared Error: 111.136
# Итерация: 533
# Mean Squared Error: 111.135
# Итерация: 534
# Mean Squared Error: 111.134
# Итерация: 535
# Mean Squared Error: 111.133
# Итерация: 536
# Mean Squared Error: 111.132
# Итерация: 537
# Mean Squared Error: 111.132
# Итерация: 538
# Mean Squared Error: 111.131
# Итерация: 539
# Mean Squared Error: 111.13
# Итерация: 540
# Mean Squared Error: 111.129
# Итерация: 541
# Mean Squared Error: 111.129
# Итерация: 542
# Mean Squared Error: 111.128
# Итерация: 543
# Mean Squared Error: 111.127
# Итерация: 544
# Mean Squared Error: 111.127
# Итерация: 545
# Mean Squared Error: 111.126
# Итерация: 546
# Mean Squared Error: 111.126
# Итерация: 547
# Mean Squared Error: 111.125
# Итерация: 548
# Mean Squared Error: 111.124
# Итерация: 549
# Mean Squared Error: 111.124
# Итерация: 550
# Mean Squared Error: 111.123
# Итерация: 551
# Mean Squared Error: 111.123
# Итерация: 552
# Mean Squared Error: 111.122
# Итерация: 553
# Mean Squared Error: 111.122
# Итерация: 554
# Mean Squared Error: 111.121
# Итерация: 555
# Mean Squared Error: 111.12
# Итерация: 556
# Mean Squared Error: 111.12
# Итерация: 557
# Mean Squared Error: 111.12
# Итерация: 558
# Mean Squared Error: 111.119
# Итерация: 559
# Mean Squared Error: 111.119
# Итерация: 560
# Mean Squared Error: 111.118
# Итерация: 561
# Mean Squared Error: 111.118
# Итерация: 562
# Mean Squared Error: 111.117
# Итерация: 563
# Mean Squared Error: 111.117
# Итерация: 564
# Mean Squared Error: 111.116
# Итерация: 565
# Mean Squared Error: 111.116
# Итерация: 566
# Mean Squared Error: 111.116
# Итерация: 567
# Mean Squared Error: 111.115
# Итерация: 568
# Mean Squared Error: 111.115
# Итерация: 569
# Mean Squared Error: 111.114
# Итерация: 570
# Mean Squared Error: 111.114
# Итерация: 571
# Mean Squared Error: 111.114
# Итерация: 572
# Mean Squared Error: 111.113
# Итерация: 573
# Mean Squared Error: 111.113
# Итерация: 574
# Mean Squared Error: 111.113
# Итерация: 575
# Mean Squared Error: 111.112
# Итерация: 576
# Mean Squared Error: 111.112
# Итерация: 577
# Mean Squared Error: 111.112
# Итерация: 578
# Mean Squared Error: 111.111
# Итерация: 579
# Mean Squared Error: 111.111
# Итерация: 580
# Mean Squared Error: 111.111
# Итерация: 581
# Mean Squared Error: 111.11
# Итерация: 582
# Mean Squared Error: 111.11
# Итерация: 583
# Mean Squared Error: 111.11
# Итерация: 584
# Mean Squared Error: 111.11
# Итерация: 585
# Mean Squared Error: 111.109
# Итерация: 586
# Mean Squared Error: 111.109
# Итерация: 587
# Mean Squared Error: 111.109
# Итерация: 588
# Mean Squared Error: 111.109
# Итерация: 589
# Mean Squared Error: 111.108
# Итерация: 590
# Mean Squared Error: 111.108
# Итерация: 591
# Mean Squared Error: 111.108
# Итерация: 592
# Mean Squared Error: 111.108
# Итерация: 593
# Mean Squared Error: 111.107
# Итерация: 594
# Mean Squared Error: 111.107
# Итерация: 595
# Mean Squared Error: 111.107
# Итерация: 596
# Mean Squared Error: 111.107
# Итерация: 597
# Mean Squared Error: 111.106
# Итерация: 598
# Mean Squared Error: 111.106
# Итерация: 599
# Mean Squared Error: 111.106
# Итерация: 600
# Mean Squared Error: 111.106
# Итерация: 601
# Mean Squared Error: 111.106
# Итерация: 602
# Mean Squared Error: 111.106
# Итерация: 603
# Mean Squared Error: 111.105
# Итерация: 604
# Mean Squared Error: 111.105
# Итерация: 605
# Mean Squared Error: 111.105
# Итерация: 606
# Mean Squared Error: 111.105
# Итерация: 607
# Mean Squared Error: 111.105
# Итерация: 608
# Mean Squared Error: 111.104
# Итерация: 609
# Mean Squared Error: 111.104
# Итерация: 610
# Mean Squared Error: 111.104
# Итерация: 611
# Mean Squared Error: 111.104
# Итерация: 612
# Mean Squared Error: 111.104
# Итерация: 613
# Mean Squared Error: 111.104
# Итерация: 614
# Mean Squared Error: 111.104
# Итерация: 615
# Mean Squared Error: 111.103
# Итерация: 616
# Mean Squared Error: 111.103
# Итерация: 617
# Mean Squared Error: 111.103
# Итерация: 618
# Mean Squared Error: 111.103
# Итерация: 619
# Mean Squared Error: 111.103
# Итерация: 620
# Mean Squared Error: 111.103
# Итерация: 621
# Mean Squared Error: 111.103
# Итерация: 622
# Mean Squared Error: 111.102
# Итерация: 623
# Mean Squared Error: 111.102
# Итерация: 624
# Mean Squared Error: 111.102
# Итерация: 625
# Mean Squared Error: 111.102
# Итерация: 626
# Mean Squared Error: 111.102
# Итерация: 627
# Mean Squared Error: 111.102
# Итерация: 628
# Mean Squared Error: 111.102
# Итерация: 629
# Mean Squared Error: 111.102
# Итерация: 630
# Mean Squared Error: 111.102
# Итерация: 631
# Mean Squared Error: 111.102

# %%
print(f'Веса при признаках: {next_weights[:]}')
print(f'Настоящие веса линейной регрессии: {coefficients}')
# Out:
# Веса при признаках: [16.04201752 26.21559011 95.06406426 -0.43342483]
# Настоящие веса линейной регрессии: [17.59034817 29.10379758 96.13877718]

# %%
import plotly
import plotly.graph_objs as go
